# %% [markdown]
# <a href="https://colab.research.google.com/github/yukanaya24/project-1_cvbasic/blob/mikano/(ver1_mikano)super_resolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # On how to train and test a deep neural network for the super-resolution task.
# > Prepared by Man M. Ho

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/Lectures/Computer Vision/ch7 image super resolution
# Out:
# Mounted at /content/gdrive
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Lectures/Computer Vision/ch7 image super resolution'
# /content

# %% [markdown]
# # Import Libraries

# %%
# For Path Processing
from os.path import exists, join, basename
from os import makedirs, remove, getcwd, listdir

# To download and extract datasets
from six.moves import urllib
import tarfile

# For Datasets and Transformation
from PIL import Image
import torch.utils.data as data
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, ToTensor, Resize

# For Network Architecture
import torch
import torch.nn as nn
import torch.nn.init as init

# PyTorch Optimizer
import torch.optim as optim

# Others
import numpy as np
from math import log10
import matplotlib.pyplot as plt # For plotting

# %% [markdown]
# # Data Preparation and Dataset
#
# Here is the Python code for downloading and extracting the dataset.

# %%
def download_bsds300(dest="dataset"):
    current_dir = getcwd()
    output_image_dir = join(current_dir, dest, "BSDS300/images")

    if not exists(output_image_dir):
        makedirs(dest)
        url = "http://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300-images.tgz"
        print("Downloading Dataset at ", url)

        data = urllib.request.urlopen(url)

        file_path = join(dest, basename(url))
        with open(file_path, 'wb') as f:
            f.write(data.read())

        print("Extracting Data")
        with tarfile.open(file_path) as tar:
            for item in tar:
                tar.extract(item, dest)

        remove(file_path)
    print('Done! Extracted Dataset is saved at : ' + join(output_image_dir))

# %%
download_bsds300()
# Out:
# Downloading Dataset at  http://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300-images.tgz
# Extracting Data
# Done! Extracted Dataset is saved at : /content/dataset/BSDS300/images

# %% [markdown]
# Now we have downloaded the dataset, let's prepare for the dataloader!

# %%
# Check whether your file ends with the exts ".png", ".jpg", and ".jpeg".
def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg"])

# Load image using PIL.Image and convert RGB to YCbCr,
# where: Y is luma/gray component, Cb and CR are chroma/color components.
# In this work, we only up-sample the Y.
def load_img(filepath):
    img = Image.open(filepath).convert('YCbCr')
    y, _, _ = img.split()
    return y

class DatasetFromFolder(data.Dataset):
    def __init__(self, image_dir, input_transform=None, target_transform=None):
        super(DatasetFromFolder, self).__init__()
        self.image_filenames = [join(image_dir, x) for x in listdir(image_dir) if is_image_file(x)]

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        # Load Images
        input = load_img(self.image_filenames[index])
        target = input.copy()

        # Input is resize 1/scale as described in the function input_transform
        if self.input_transform:
            input = self.input_transform(input)
        # Target is the original image
        if self.target_transform:
            target = self.target_transform(target)

        return input, target

    def __len__(self):
        return len(self.image_filenames)

# result the suitable crop_size for upscale_factor
def calculate_valid_crop_size(crop_size, upscale_factor):
    return crop_size - (crop_size % upscale_factor)


def input_transform(crop_size, upscale_factor):
    return Compose([
        CenterCrop(crop_size),
        Resize(crop_size // upscale_factor),
        ToTensor(),
    ])


def target_transform(crop_size):
    return Compose([
        CenterCrop(crop_size),
        ToTensor(),
    ])


# This result Pytorch Dataset for training
def get_training_set(root_dir, upscale_factor):
    train_dir = join(root_dir, "train")
    crop_size = calculate_valid_crop_size(256, upscale_factor)

    return DatasetFromFolder(train_dir,
                             input_transform=input_transform(crop_size, upscale_factor),
                             target_transform=target_transform(crop_size))

# This result Pytorch Dataset for testing
def get_test_set(root_dir, upscale_factor):
    test_dir = join(root_dir, "test")
    crop_size = calculate_valid_crop_size(256, upscale_factor)

    return DatasetFromFolder(test_dir,
                             input_transform=input_transform(crop_size, upscale_factor),
                             target_transform=target_transform(crop_size))

# %% [markdown]
# # Network Architecture
# ![Screenshot_308.png](data:image/png;base64,...)

# %% [markdown]
# Regarding the network architecture, we utilize Efficient Sub-Pixel Convolutional Neural Network (ESPCN, https://arxiv.org/pdf/1609.05158.pdf
# ) with N convolutional layers (they set N=4 in the code), the feature size in the inference order are as:
#
# ---
# Input Y: H x W x 1
#
# ---
# Conv1 x ReLU:
#
# H x W x 1 --> H x W x 64
#
# ---
# Conv2 x ReLU:
#
# H x W x 64 --> H x W x 64
#
# ---
# Conv3 x ReLU:
#
# H x W x 64 --> H x W x 32
#
# ---
# Conv4:
#
# H x W x 32 --> H x W x (upscale_factor ** 2)
#
# ---
# Pixel_Shuffle:
#
# H x W x (upscale_factor ** 2) --> H' x W' x 1
#
# where:
#
# H' = H * upscale_factor
#
# W' = W * upscale_factor
#
# Pixel shuffle technique converts a feature map of H x W x (upscale_factor**2) to the high-resolution output image H' x W' x 1
#
# ---
# A code for the network is as:

# %%
class Net(nn.Module):
    def __init__(self, upscale_factor):
        super(Net, self).__init__()

        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
        self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
        self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
        self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
        self.pixel_shuffle = nn.PixelShuffle(upscale_factor)

        self._initialize_weights()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.relu(self.conv3(x))
        x = self.pixel_shuffle(self.conv4(x))
        return x

    def _initialize_weights(self):
        init.orthogonal_(self.conv1.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv2.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv3.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv4.weight)

# %% [markdown]
# # Train Models

# %% [markdown]
# ## Set hyperparameters

# %%
args = {}
# here is where BSD300 dataset is saved
args['root_dir'] = './dataset/BSDS300/images'
# super resolution upscale factor
args['upscale_factor'] = 2
# training batch size
args['batchSize'] = 64
# testing batch size
args['testBatchSize'] = 10
# number of epochs to train for
args['nEpochs'] = 50
# Learning Rate
args['lr'] = 0.01
# number of threads for data loader to use
args['threads'] = 4
# random seed to use
args['seed'] = 42

# %% [markdown]
# ## This keeps your random function consistent for every run so that you can reproduce your results.

# %%
torch.manual_seed(args['seed'])

# %% [markdown]
# ## Declare training and test dataloader

# %%
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# ## Declare model and criteria

# %%
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()

# %% [markdown]
# ## Declare optimizer
#
# Adam: https://arxiv.org/abs/1412.6980

# %%
optimizer = optim.Adam(model.parameters(), lr=args['lr'])

# %% [markdown]
# ## Training function

# %%
def train(epoch):
    print('Epoch: {}'.format(epoch))
    epoch_loss = 0
    for iteration, batch in enumerate(training_data_loader, 1):
        input, target = batch[0].cuda(), batch[1].cuda()

        optimizer.zero_grad()
        loss = training_loss_fn(model(input), target)
        epoch_loss += loss.item()
        loss.backward()
        optimizer.step()

        # print("===> Epoch[{}]({}/{}): Loss: {:.4f}".format(epoch, iteration, len(training_data_loader), loss.item()))

    print("===> Train: Avg. Loss: {:.4f}".format(epoch_loss / len(training_data_loader)))
    return epoch_loss / len(training_data_loader)

# %% [markdown]
# ## Test function

# %%
def test():
    avg_psnr = 0
    with torch.no_grad():
        for batch in testing_data_loader:
            input, target = batch[0].cuda(), batch[1].cuda()

            prediction = model(input)
            mse = mse_fn(prediction, target)
            psnr = 10 * log10(1 / mse.item())
            avg_psnr += psnr
    print("===> Test: Avg. PSNR: {:.4f} dB".format(avg_psnr / len(testing_data_loader)))
    return avg_psnr / len(testing_data_loader)

# %% [markdown]
# ## Save checkpoint

# %%
def save_checkpoint(epoch, model_name='model'):
    model_out_path = model_name + "_epoch_{}.pth".format(epoch)
    torch.save(model, model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))

# %% [markdown]
# ## Train models

# %% [markdown]
# We are using BSDS300 dataset, MSE for the loss function, and a network architecture with 4 convolutional layers.

# %%
base_train_errors = []
base_test_psnrs = []
for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    base_train_errors.append(train_error)
    base_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_base')

# Plotting errors
## Note for plot function, Args from left to right:
### range,
### list of values,
### color such as 'g' -> green, 'b' --> blue, 'r' --> red
#### See more colors here https://matplotlib.org/stable/gallery/color/named_colors.html
### label
plt.figure()
plt.plot(range(1, args['nEpochs'] + 1), base_train_errors, 'g', label='Base Model')
# plt.plot(range(1, args['nEpochs'] + 1), bsds500_train_errors, 'b', label='BSDS500 Model') # You can add another model like this
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

plt.figure()
plt.plot(range(1, args['nEpochs'] + 1), base_test_psnrs, 'g', label='Base Model')
# plt.plot(range(1, args['nEpochs'] + 1), bsds500_test_psnrs, 'b', label='Base Model')# You can add another model like this
plt.title('Val PSNR')
plt.xlabel('Epoch')
plt.ylabel('PSNR')
plt.legend()
plt.show()
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 3.2618
# ===> Test: Avg. PSNR: 6.2649 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.1735
# ===> Test: Avg. PSNR: 13.8151 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.0519
# ===> Test: Avg. PSNR: 15.9871 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.0329
# ===> Test: Avg. PSNR: 13.0936 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0370
# ===> Test: Avg. PSNR: 17.0040 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0240
# ===> Test: Avg. PSNR: 17.0027 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0190
# ===> Test: Avg. PSNR: 16.5300 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0198
# ===> Test: Avg. PSNR: 17.5345 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0177
# ===> Test: Avg. PSNR: 17.8555 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0152
# ===> Test: Avg. PSNR: 17.8309 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0154
# ===> Test: Avg. PSNR: 18.2761 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0139
# ===> Test: Avg. PSNR: 18.7203 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0133
# ===> Test: Avg. PSNR: 18.9706 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0123
# ===> Test: Avg. PSNR: 19.0514 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0124
# ===> Test: Avg. PSNR: 19.1506 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0111
# ===> Test: Avg. PSNR: 19.2224 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0121
# ===> Test: Avg. PSNR: 19.3097 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0111
# ===> Test: Avg. PSNR: 19.3839 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0105
# ===> Test: Avg. PSNR: 19.4387 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.4659 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0107
# ===> Test: Avg. PSNR: 19.5124 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0111
# ===> Test: Avg. PSNR: 19.5567 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0103
# ===> Test: Avg. PSNR: 19.5911 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0101
# ===> Test: Avg. PSNR: 19.6220 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0109
# ===> Test: Avg. PSNR: 19.6679 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0099
# ===> Test: Avg. PSNR: 19.7059 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.7524 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0105
# ===> Test: Avg. PSNR: 19.7959 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0106
# ===> Test: Avg. PSNR: 19.8353 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 19.8793 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0100
# ===> Test: Avg. PSNR: 19.9209 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 19.9636 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0101
# ===> Test: Avg. PSNR: 20.0022 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0093
# ===> Test: Avg. PSNR: 20.0436 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 20.0928 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0098
# ===> Test: Avg. PSNR: 20.1268 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0093
# ===> Test: Avg. PSNR: 20.1524 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0085
# ===> Test: Avg. PSNR: 20.2157 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0090
# ===> Test: Avg. PSNR: 20.2560 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0091
# ===> Test: Avg. PSNR: 20.2960 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0088
# ===> Test: Avg. PSNR: 20.3417 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0090
# ===> Test: Avg. PSNR: 20.3936 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.4291 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0091
# ===> Test: Avg. PSNR: 20.4766 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0084
# ===> Test: Avg. PSNR: 20.5232 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.5592 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0081
# ===> Test: Avg. PSNR: 20.6073 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.6355 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.6827 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0083
# ===> Test: Avg. PSNR: 20.7219 dB
# Checkpoint saved to model_base_epoch_50.pth

# %% [markdown]
# # Tasks
# Task 1.学習済みモデルを用いて、1枚の画像に対するテスト結果を確認する（20点）
#
# Task 2.損失関数に関するアブレーションスタディを実施する。各損失関数を用いた際のモデル性能（PSNR）を比較する。（30点）
#
# Task 3.ネットワーク構造やハイパーパラメータなどを調整し、性能（PSNR）の向上を図る（50点）
#
# 上記に示したトレーニング損失や検証時のPSNRのプロット方法を参考にしてください。

# %% [markdown]
# ##Task 1. Test the trained model on your own images
#
# The run function is as:

# %%
def run_model(input_image, output_filename, model_path):
  img = Image.open(input_image).convert('YCbCr')
  y, cb, cr = img.split()

  model = torch.load(model_path, weights_only=False)
  img_to_tensor = ToTensor()
  input = img_to_tensor(y).view(1, -1, y.size[1], y.size[0])

  model = model.cuda()
  input = input.cuda()

  out = model(input)
  out = out.cpu()
  out_img_y = out[0].detach().numpy()
  out_img_y *= 255.0
  out_img_y = out_img_y.clip(0, 255)
  out_img_y = Image.fromarray(np.uint8(out_img_y[0]), mode='L')

  out_img_cb = cb.resize(out_img_y.size, Image.BICUBIC)
  out_img_cr = cr.resize(out_img_y.size, Image.BICUBIC)
  out_img = Image.merge('YCbCr', [out_img_y, out_img_cb, out_img_cr]).convert('RGB')

  out_img.save(output_filename)
  print('Output image saved to ', output_filename)
  return img.convert('RGB'), out_img

# %%
# An example
input_image = "./dataset/BSDS300/images/test/101085.jpg"
output_filename = "101085_x2.jpg"

model_path = "model_base_epoch_50.pth"
img, out_img = run_model(input_image, output_filename, model_path)
# Out:
# Output image saved to  101085_x2.jpg

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=321x481>

# %%
out_img
# Out:
# <PIL.Image.Image image mode=RGB size=642x962>

# %% [markdown]
# ##Task 2. Conduct an ablation study on loss function.
#
# MSE（Mean Square Error：平均二乗誤差）以外にも、画像生成に用いられる損失関数は多数存在します。以下はその一部です：
#
# L1: https://pytorch.org/docs/stable/generated/torch.nn.L1Loss.html#torch.nn.L1Loss
#
# L1 Smooth: https://pytorch.org/docs/stable/generated/torch.nn.SmoothL1Loss.html#torch.nn.SmoothL1Loss
#
# Huber Loss: https://pytorch.org/docs/stable/generated/torch.nn.HuberLoss.html#torch.nn.HuberLoss
#
# MS-SSIM: https://github.com/jorge-pessoa/pytorch-msssim
#
# LPIPS: https://github.com/richzhang/PerceptualSimilarity
#
# MSE以外の損失関数に変更し、結果を分析してください。
# 以下はL1損失関数に変更する例です。

# %%
# Baseline, training_loss_fn is commented for changing
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
# training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)

# Change the Training Loss Function
training_loss_fn = nn.L1Loss()

l1loss_train_errors = []
l1loss_test_psnrs = []

for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    l1loss_train_errors.append(train_error)
    l1loss_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_l1loss')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 1.6010
# ===> Test: Avg. PSNR: 7.1459 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.2816
# ===> Test: Avg. PSNR: 14.4392 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.1480
# ===> Test: Avg. PSNR: 15.2608 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.1105
# ===> Test: Avg. PSNR: 15.1463 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0980
# ===> Test: Avg. PSNR: 17.8441 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0859
# ===> Test: Avg. PSNR: 19.1120 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0759
# ===> Test: Avg. PSNR: 19.6379 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0720
# ===> Test: Avg. PSNR: 19.5318 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0684
# ===> Test: Avg. PSNR: 19.1519 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0705
# ===> Test: Avg. PSNR: 19.3016 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0740
# ===> Test: Avg. PSNR: 19.4246 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0650
# ===> Test: Avg. PSNR: 20.2101 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0661
# ===> Test: Avg. PSNR: 20.2948 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0629
# ===> Test: Avg. PSNR: 20.1452 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0631
# ===> Test: Avg. PSNR: 20.4107 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0615
# ===> Test: Avg. PSNR: 20.6703 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0607
# ===> Test: Avg. PSNR: 20.6137 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0576
# ===> Test: Avg. PSNR: 20.4360 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0588
# ===> Test: Avg. PSNR: 20.8053 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0561
# ===> Test: Avg. PSNR: 21.0753 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0584
# ===> Test: Avg. PSNR: 20.6915 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0628
# ===> Test: Avg. PSNR: 19.0582 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0674
# ===> Test: Avg. PSNR: 19.3153 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0737
# ===> Test: Avg. PSNR: 20.5725 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0736
# ===> Test: Avg. PSNR: 17.6498 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0842
# ===> Test: Avg. PSNR: 20.5139 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0732
# ===> Test: Avg. PSNR: 19.1467 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0716
# ===> Test: Avg. PSNR: 21.0003 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0616
# ===> Test: Avg. PSNR: 21.0383 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0565
# ===> Test: Avg. PSNR: 21.4064 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0540
# ===> Test: Avg. PSNR: 21.4719 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0568
# ===> Test: Avg. PSNR: 21.5107 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0617
# ===> Test: Avg. PSNR: 21.5188 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0592
# ===> Test: Avg. PSNR: 21.4642 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0568
# ===> Test: Avg. PSNR: 21.5787 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0550
# ===> Test: Avg. PSNR: 21.9215 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0543
# ===> Test: Avg. PSNR: 22.0504 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0488
# ===> Test: Avg. PSNR: 21.6024 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0514
# ===> Test: Avg. PSNR: 21.2742 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0558
# ===> Test: Avg. PSNR: 20.8527 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0581
# ===> Test: Avg. PSNR: 22.2849 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0528
# ===> Test: Avg. PSNR: 22.3923 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0579
# ===> Test: Avg. PSNR: 21.6589 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0603
# ===> Test: Avg. PSNR: 20.9600 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0597
# ===> Test: Avg. PSNR: 22.2682 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0538
# ===> Test: Avg. PSNR: 21.1358 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0531
# ===> Test: Avg. PSNR: 21.0488 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0569
# ===> Test: Avg. PSNR: 22.2583 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0466
# ===> Test: Avg. PSNR: 22.1270 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0477
# ===> Test: Avg. PSNR: 22.0843 dB
# Checkpoint saved to model_l1loss_epoch_50.pth

# %% [markdown]
# ##Task 3 Optimization

# %% [markdown]
# ###3.1 Modify hyper parameters

# %%
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)



args['nEpochs'] = 500

epoch500extend_train_errors = []
epoch500extend_test_psnrs = []

for epoch in range(1, args['nEpochs']  + 1):
    train_error = train(epoch)
    test_psnr = test()
    epoch500extend_train_errors.append(train_error)
    epoch500extend_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_epoch500extend')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 3.2618
# ===> Test: Avg. PSNR: 6.2649 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.1735
# ===> Test: Avg. PSNR: 13.8151 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.0519
# ===> Test: Avg. PSNR: 15.9871 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.0329
# ===> Test: Avg. PSNR: 13.0936 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0370
# ===> Test: Avg. PSNR: 17.0040 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0240
# ===> Test: Avg. PSNR: 17.0027 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0190
# ===> Test: Avg. PSNR: 16.5300 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0198
# ===> Test: Avg. PSNR: 17.5345 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0177
# ===> Test: Avg. PSNR: 17.8555 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0152
# ===> Test: Avg. PSNR: 17.8309 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0154
# ===> Test: Avg. PSNR: 18.2761 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0139
# ===> Test: Avg. PSNR: 18.7203 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0133
# ===> Test: Avg. PSNR: 18.9706 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0123
# ===> Test: Avg. PSNR: 19.0514 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0124
# ===> Test: Avg. PSNR: 19.1506 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0111
# ===> Test: Avg. PSNR: 19.2224 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0121
# ===> Test: Avg. PSNR: 19.3097 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0111
# ===> Test: Avg. PSNR: 19.3839 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0105
# ===> Test: Avg. PSNR: 19.4387 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.4659 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0107
# ===> Test: Avg. PSNR: 19.5124 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0111
# ===> Test: Avg. PSNR: 19.5567 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0103
# ===> Test: Avg. PSNR: 19.5911 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0101
# ===> Test: Avg. PSNR: 19.6220 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0109
# ===> Test: Avg. PSNR: 19.6679 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0099
# ===> Test: Avg. PSNR: 19.7059 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.7524 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0105
# ===> Test: Avg. PSNR: 19.7959 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0106
# ===> Test: Avg. PSNR: 19.8353 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 19.8793 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0100
# ===> Test: Avg. PSNR: 19.9209 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 19.9636 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0101
# ===> Test: Avg. PSNR: 20.0022 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0093
# ===> Test: Avg. PSNR: 20.0436 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 20.0928 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0098
# ===> Test: Avg. PSNR: 20.1268 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0093
# ===> Test: Avg. PSNR: 20.1524 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0085
# ===> Test: Avg. PSNR: 20.2157 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0090
# ===> Test: Avg. PSNR: 20.2560 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0091
# ===> Test: Avg. PSNR: 20.2960 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0088
# ===> Test: Avg. PSNR: 20.3417 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0090
# ===> Test: Avg. PSNR: 20.3936 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.4291 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0091
# ===> Test: Avg. PSNR: 20.4766 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0084
# ===> Test: Avg. PSNR: 20.5232 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.5592 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0081
# ===> Test: Avg. PSNR: 20.6073 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.6355 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.6827 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0083
# ===> Test: Avg. PSNR: 20.7219 dB
# Epoch: 51
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.7674 dB
# Epoch: 52
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.8086 dB
# Epoch: 53
# ===> Train: Avg. Loss: 0.0083
# ===> Test: Avg. PSNR: 20.8314 dB
# Epoch: 54
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.8708 dB
# Epoch: 55
# ===> Train: Avg. Loss: 0.0077
# ===> Test: Avg. PSNR: 20.8896 dB
# Epoch: 56
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.9190 dB
# Epoch: 57
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.9563 dB
# Epoch: 58
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.9849 dB
# Epoch: 59
# ===> Train: Avg. Loss: 0.0081
# ===> Test: Avg. PSNR: 21.0129 dB
# Epoch: 60
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 21.0379 dB
# Epoch: 61
# ===> Train: Avg. Loss: 0.0072
# ===> Test: Avg. PSNR: 21.0593 dB
# Epoch: 62
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 21.0957 dB
# Epoch: 63
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 21.1187 dB
# Epoch: 64
# ===> Train: Avg. Loss: 0.0072
# ===> Test: Avg. PSNR: 21.1444 dB
# Epoch: 65
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 21.1705 dB
# Epoch: 66
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 21.1986 dB
# Epoch: 67
# ===> Train: Avg. Loss: 0.0068
# ===> Test: Avg. PSNR: 21.2252 dB
# Epoch: 68
# ===> Train: Avg. Loss: 0.0073
# ===> Test: Avg. PSNR: 21.2512 dB
# Epoch: 69
# ===> Train: Avg. Loss: 0.0072
# ===> Test: Avg. PSNR: 21.2699 dB
# Epoch: 70
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.3025 dB
# Epoch: 71
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.3222 dB
# Epoch: 72
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.3544 dB
# Epoch: 73
# ===> Train: Avg. Loss: 0.0068
# ===> Test: Avg. PSNR: 21.3809 dB
# Epoch: 74
# ===> Train: Avg. Loss: 0.0070
# ===> Test: Avg. PSNR: 21.4061 dB
# Epoch: 75
# ===> Train: Avg. Loss: 0.0072
# ===> Test: Avg. PSNR: 21.4310 dB
# Epoch: 76
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.4412 dB
# Epoch: 77
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.4744 dB
# Epoch: 78
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.5075 dB
# Epoch: 79
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.5377 dB
# Epoch: 80
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.5631 dB
# Epoch: 81
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.5945 dB
# Epoch: 82
# ===> Train: Avg. Loss: 0.0068
# ===> Test: Avg. PSNR: 21.6237 dB
# Epoch: 83
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.6509 dB
# Epoch: 84
# ===> Train: Avg. Loss: 0.0059
# ===> Test: Avg. PSNR: 21.6383 dB
# Epoch: 85
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.7187 dB
# Epoch: 86
# ===> Train: Avg. Loss: 0.0067
# ===> Test: Avg. PSNR: 21.7175 dB
# Epoch: 87
# ===> Train: Avg. Loss: 0.0059
# ===> Test: Avg. PSNR: 21.7860 dB
# Epoch: 88
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 21.7890 dB
# Epoch: 89
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.8375 dB
# Epoch: 90
# ===> Train: Avg. Loss: 0.0061
# ===> Test: Avg. PSNR: 21.8933 dB
# Epoch: 91
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.9317 dB
# Epoch: 92
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 21.9727 dB
# Epoch: 93
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.0134 dB
# Epoch: 94
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 22.0465 dB
# Epoch: 95
# ===> Train: Avg. Loss: 0.0059
# ===> Test: Avg. PSNR: 22.1048 dB
# Epoch: 96
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.1415 dB
# Epoch: 97
# ===> Train: Avg. Loss: 0.0059
# ===> Test: Avg. PSNR: 22.1948 dB
# Epoch: 98
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 22.2276 dB
# Epoch: 99
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 22.2918 dB
# Epoch: 100
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 22.3411 dB
# Epoch: 101
# ===> Train: Avg. Loss: 0.0054
# ===> Test: Avg. PSNR: 22.3872 dB
# Epoch: 102
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.4289 dB
# Epoch: 103
# ===> Train: Avg. Loss: 0.0056
# ===> Test: Avg. PSNR: 22.4794 dB
# Epoch: 104
# ===> Train: Avg. Loss: 0.0059
# ===> Test: Avg. PSNR: 22.5219 dB
# Epoch: 105
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 22.5559 dB
# Epoch: 106
# ===> Train: Avg. Loss: 0.0056
# ===> Test: Avg. PSNR: 22.5712 dB
# Epoch: 107
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.5931 dB
# Epoch: 108
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.6982 dB
# Epoch: 109
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.7370 dB
# Epoch: 110
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.7774 dB
# Epoch: 111
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.8109 dB
# Epoch: 112
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.8546 dB
# Epoch: 113
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.8912 dB
# Epoch: 114
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.9313 dB
# Epoch: 115
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 22.9643 dB
# Epoch: 116
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 23.0025 dB
# Epoch: 117
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.0248 dB
# Epoch: 118
# ===> Train: Avg. Loss: 0.0049
# ===> Test: Avg. PSNR: 23.0693 dB
# Epoch: 119
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 23.0826 dB
# Epoch: 120
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.1418 dB
# Epoch: 121
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 23.1801 dB
# Epoch: 122
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 23.2101 dB
# Epoch: 123
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.2447 dB
# Epoch: 124
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.2777 dB
# Epoch: 125
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.3107 dB
# Epoch: 126
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.3435 dB
# Epoch: 127
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.3709 dB
# Epoch: 128
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.4103 dB
# Epoch: 129
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.4401 dB
# Epoch: 130
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.4642 dB
# Epoch: 131
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.4917 dB
# Epoch: 132
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.5103 dB
# Epoch: 133
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.5559 dB
# Epoch: 134
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.5811 dB
# Epoch: 135
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.6104 dB
# Epoch: 136
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.6443 dB
# Epoch: 137
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.6710 dB
# Epoch: 138
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.6969 dB
# Epoch: 139
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.7263 dB
# Epoch: 140
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.7591 dB
# Epoch: 141
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.7771 dB
# Epoch: 142
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.7988 dB
# Epoch: 143
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.8447 dB
# Epoch: 144
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.8991 dB
# Epoch: 145
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.9454 dB
# Epoch: 146
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.9897 dB
# Epoch: 147
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.0282 dB
# Epoch: 148
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.0653 dB
# Epoch: 149
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.0898 dB
# Epoch: 150
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.1083 dB
# Epoch: 151
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.1682 dB
# Epoch: 152
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.2027 dB
# Epoch: 153
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.2341 dB
# Epoch: 154
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.2581 dB
# Epoch: 155
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.2805 dB
# Epoch: 156
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.3410 dB
# Epoch: 157
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.3820 dB
# Epoch: 158
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.4180 dB
# Epoch: 159
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.4524 dB
# Epoch: 160
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.4834 dB
# Epoch: 161
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.5271 dB
# Epoch: 162
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.5515 dB
# Epoch: 163
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.5472 dB
# Epoch: 164
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.6363 dB
# Epoch: 165
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.5781 dB
# Epoch: 166
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.6961 dB
# Epoch: 167
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.6971 dB
# Epoch: 168
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.7220 dB
# Epoch: 169
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.7849 dB
# Epoch: 170
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.7745 dB
# Epoch: 171
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.6902 dB
# Epoch: 172
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.8291 dB
# Epoch: 173
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.8938 dB
# Epoch: 174
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.9501 dB
# Epoch: 175
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.8627 dB
# Epoch: 176
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.9864 dB
# Epoch: 177
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.9937 dB
# Epoch: 178
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.8619 dB
# Epoch: 179
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 25.0851 dB
# Epoch: 180
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.0048 dB
# Epoch: 181
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 23.0110 dB
# Epoch: 182
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.2624 dB
# Epoch: 183
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.8364 dB
# Epoch: 184
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.0608 dB
# Epoch: 185
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 23.6702 dB
# Epoch: 186
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 25.1919 dB
# Epoch: 187
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.5714 dB
# Epoch: 188
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.2242 dB
# Epoch: 189
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2220 dB
# Epoch: 190
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.1807 dB
# Epoch: 191
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2778 dB
# Epoch: 192
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.2513 dB
# Epoch: 193
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.3149 dB
# Epoch: 194
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.3276 dB
# Epoch: 195
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3206 dB
# Epoch: 196
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3564 dB
# Epoch: 197
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.3719 dB
# Epoch: 198
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.3973 dB
# Epoch: 199
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.3911 dB
# Epoch: 200
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4236 dB
# Epoch: 201
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3964 dB
# Epoch: 202
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 25.4580 dB
# Epoch: 203
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.4632 dB
# Epoch: 204
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4775 dB
# Epoch: 205
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.4953 dB
# Epoch: 206
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5175 dB
# Epoch: 207
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5186 dB
# Epoch: 208
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5436 dB
# Epoch: 209
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5490 dB
# Epoch: 210
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.5656 dB
# Epoch: 211
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.5819 dB
# Epoch: 212
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5947 dB
# Epoch: 213
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6074 dB
# Epoch: 214
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6035 dB
# Epoch: 215
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6300 dB
# Epoch: 216
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6395 dB
# Epoch: 217
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6523 dB
# Epoch: 218
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6671 dB
# Epoch: 219
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.6771 dB
# Epoch: 220
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.6904 dB
# Epoch: 221
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7027 dB
# Epoch: 222
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7166 dB
# Epoch: 223
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.7226 dB
# Epoch: 224
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7189 dB
# Epoch: 225
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7528 dB
# Epoch: 226
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.7549 dB
# Epoch: 227
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.7771 dB
# Epoch: 228
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7900 dB
# Epoch: 229
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8015 dB
# Epoch: 230
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8131 dB
# Epoch: 231
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8247 dB
# Epoch: 232
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8236 dB
# Epoch: 233
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8108 dB
# Epoch: 234
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8522 dB
# Epoch: 235
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8682 dB
# Epoch: 236
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8687 dB
# Epoch: 237
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8752 dB
# Epoch: 238
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.8915 dB
# Epoch: 239
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9077 dB
# Epoch: 240
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9026 dB
# Epoch: 241
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8054 dB
# Epoch: 242
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7565 dB
# Epoch: 243
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8088 dB
# Epoch: 244
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9634 dB
# Epoch: 245
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9690 dB
# Epoch: 246
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9825 dB
# Epoch: 247
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.9861 dB
# Epoch: 248
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0009 dB
# Epoch: 249
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.0114 dB
# Epoch: 250
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0204 dB
# Epoch: 251
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0143 dB
# Epoch: 252
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2850 dB
# Epoch: 253
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2671 dB
# Epoch: 254
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.5808 dB
# Epoch: 255
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6462 dB
# Epoch: 256
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5369 dB
# Epoch: 257
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 24.5430 dB
# Epoch: 258
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 24.7837 dB
# Epoch: 259
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 23.3818 dB
# Epoch: 260
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 26.0998 dB
# Epoch: 261
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 23.9398 dB
# Epoch: 262
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 22.9743 dB
# Epoch: 263
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 23.8007 dB
# Epoch: 264
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 24.7352 dB
# Epoch: 265
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 22.4265 dB
# Epoch: 266
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.0941 dB
# Epoch: 267
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 24.9317 dB
# Epoch: 268
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.6064 dB
# Epoch: 269
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6650 dB
# Epoch: 270
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.7665 dB
# Epoch: 271
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9739 dB
# Epoch: 272
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 26.0247 dB
# Epoch: 273
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1140 dB
# Epoch: 274
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1363 dB
# Epoch: 275
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1422 dB
# Epoch: 276
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1292 dB
# Epoch: 277
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1122 dB
# Epoch: 278
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1787 dB
# Epoch: 279
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1824 dB
# Epoch: 280
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1947 dB
# Epoch: 281
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1951 dB
# Epoch: 282
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1932 dB
# Epoch: 283
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2215 dB
# Epoch: 284
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2278 dB
# Epoch: 285
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2320 dB
# Epoch: 286
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2410 dB
# Epoch: 287
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2483 dB
# Epoch: 288
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2442 dB
# Epoch: 289
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2211 dB
# Epoch: 290
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2633 dB
# Epoch: 291
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.2569 dB
# Epoch: 292
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2735 dB
# Epoch: 293
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2865 dB
# Epoch: 294
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2946 dB
# Epoch: 295
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3017 dB
# Epoch: 296
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2871 dB
# Epoch: 297
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.3129 dB
# Epoch: 298
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3189 dB
# Epoch: 299
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3246 dB
# Epoch: 300
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3294 dB
# Epoch: 301
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3349 dB
# Epoch: 302
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3400 dB
# Epoch: 303
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3454 dB
# Epoch: 304
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3519 dB
# Epoch: 305
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3571 dB
# Epoch: 306
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3613 dB
# Epoch: 307
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3669 dB
# Epoch: 308
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.3718 dB
# Epoch: 309
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3715 dB
# Epoch: 310
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3821 dB
# Epoch: 311
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.3878 dB
# Epoch: 312
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3919 dB
# Epoch: 313
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3864 dB
# Epoch: 314
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4021 dB
# Epoch: 315
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3852 dB
# Epoch: 316
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4091 dB
# Epoch: 317
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.3846 dB
# Epoch: 318
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4187 dB
# Epoch: 319
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.4233 dB
# Epoch: 320
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3858 dB
# Epoch: 321
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4240 dB
# Epoch: 322
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3438 dB
# Epoch: 323
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4395 dB
# Epoch: 324
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4165 dB
# Epoch: 325
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4390 dB
# Epoch: 326
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4455 dB
# Epoch: 327
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4343 dB
# Epoch: 328
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.4614 dB
# Epoch: 329
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4654 dB
# Epoch: 330
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4694 dB
# Epoch: 331
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.4733 dB
# Epoch: 332
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4773 dB
# Epoch: 333
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4595 dB
# Epoch: 334
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.4837 dB
# Epoch: 335
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4740 dB
# Epoch: 336
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4923 dB
# Epoch: 337
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4950 dB
# Epoch: 338
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4989 dB
# Epoch: 339
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5010 dB
# Epoch: 340
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5056 dB
# Epoch: 341
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.5077 dB
# Epoch: 342
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5070 dB
# Epoch: 343
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5002 dB
# Epoch: 344
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5138 dB
# Epoch: 345
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.5169 dB
# Epoch: 346
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.4747 dB
# Epoch: 347
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5074 dB
# Epoch: 348
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5301 dB
# Epoch: 349
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5317 dB
# Epoch: 350
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5340 dB
# Epoch: 351
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5388 dB
# Epoch: 352
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5437 dB
# Epoch: 353
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5459 dB
# Epoch: 354
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5507 dB
# Epoch: 355
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5510 dB
# Epoch: 356
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5554 dB
# Epoch: 357
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5544 dB
# Epoch: 358
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5528 dB
# Epoch: 359
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.5525 dB
# Epoch: 360
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5303 dB
# Epoch: 361
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5673 dB
# Epoch: 362
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5737 dB
# Epoch: 363
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.5754 dB
# Epoch: 364
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5795 dB
# Epoch: 365
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5812 dB
# Epoch: 366
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5557 dB
# Epoch: 367
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5406 dB
# Epoch: 368
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5432 dB
# Epoch: 369
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4918 dB
# Epoch: 370
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5836 dB
# Epoch: 371
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5965 dB
# Epoch: 372
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6001 dB
# Epoch: 373
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.6027 dB
# Epoch: 374
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5984 dB
# Epoch: 375
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6065 dB
# Epoch: 376
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.5835 dB
# Epoch: 377
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6037 dB
# Epoch: 378
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.6137 dB
# Epoch: 379
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6159 dB
# Epoch: 380
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6083 dB
# Epoch: 381
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6198 dB
# Epoch: 382
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.6210 dB
# Epoch: 383
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6055 dB
# Epoch: 384
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6256 dB
# Epoch: 385
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6270 dB
# Epoch: 386
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6214 dB
# Epoch: 387
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6255 dB
# Epoch: 388
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6331 dB
# Epoch: 389
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6371 dB
# Epoch: 390
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6327 dB
# Epoch: 391
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.6003 dB
# Epoch: 392
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6420 dB
# Epoch: 393
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6339 dB
# Epoch: 394
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6436 dB
# Epoch: 395
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.6519 dB
# Epoch: 396
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6541 dB
# Epoch: 397
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6558 dB
# Epoch: 398
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6562 dB
# Epoch: 399
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6563 dB
# Epoch: 400
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6579 dB
# Epoch: 401
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6496 dB
# Epoch: 402
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6416 dB
# Epoch: 403
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.5606 dB
# Epoch: 404
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6611 dB
# Epoch: 405
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.6665 dB
# Epoch: 406
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6669 dB
# Epoch: 407
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6416 dB
# Epoch: 408
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5815 dB
# Epoch: 409
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6779 dB
# Epoch: 410
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6765 dB
# Epoch: 411
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6107 dB
# Epoch: 412
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.6318 dB
# Epoch: 413
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.6608 dB
# Epoch: 414
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5760 dB
# Epoch: 415
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6037 dB
# Epoch: 416
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6777 dB
# Epoch: 417
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2617 dB
# Epoch: 418
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6117 dB
# Epoch: 419
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5879 dB
# Epoch: 420
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5675 dB
# Epoch: 421
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6942 dB
# Epoch: 422
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6374 dB
# Epoch: 423
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6966 dB
# Epoch: 424
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6993 dB
# Epoch: 425
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5868 dB
# Epoch: 426
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.5898 dB
# Epoch: 427
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7090 dB
# Epoch: 428
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.5914 dB
# Epoch: 429
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6184 dB
# Epoch: 430
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6307 dB
# Epoch: 431
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4608 dB
# Epoch: 432
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5441 dB
# Epoch: 433
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7177 dB
# Epoch: 434
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5252 dB
# Epoch: 435
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5703 dB
# Epoch: 436
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.7141 dB
# Epoch: 437
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.4285 dB
# Epoch: 438
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.3985 dB
# Epoch: 439
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6200 dB
# Epoch: 440
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6443 dB
# Epoch: 441
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.6261 dB
# Epoch: 442
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.6114 dB
# Epoch: 443
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7265 dB
# Epoch: 444
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6083 dB
# Epoch: 445
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6706 dB
# Epoch: 446
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.6635 dB
# Epoch: 447
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.3356 dB
# Epoch: 448
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.7411 dB
# Epoch: 449
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6269 dB
# Epoch: 450
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6767 dB
# Epoch: 451
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.5466 dB
# Epoch: 452
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.4687 dB
# Epoch: 453
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2349 dB
# Epoch: 454
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.1638 dB
# Epoch: 455
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.6074 dB
# Epoch: 456
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.7496 dB
# Epoch: 457
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.7207 dB
# Epoch: 458
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.5104 dB
# Epoch: 459
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7280 dB
# Epoch: 460
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.6414 dB
# Epoch: 461
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.7433 dB
# Epoch: 462
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.7034 dB
# Epoch: 463
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6047 dB
# Epoch: 464
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7119 dB
# Epoch: 465
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.5486 dB
# Epoch: 466
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.3537 dB
# Epoch: 467
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.5524 dB
# Epoch: 468
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5705 dB
# Epoch: 469
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6227 dB
# Epoch: 470
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.0909 dB
# Epoch: 471
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1824 dB
# Epoch: 472
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.4196 dB
# Epoch: 473
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5262 dB
# Epoch: 474
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6388 dB
# Epoch: 475
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5369 dB
# Epoch: 476
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6865 dB
# Epoch: 477
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7293 dB
# Epoch: 478
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7292 dB
# Epoch: 479
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7494 dB
# Epoch: 480
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7608 dB
# Epoch: 481
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7776 dB
# Epoch: 482
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7793 dB
# Epoch: 483
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7632 dB
# Epoch: 484
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7587 dB
# Epoch: 485
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7292 dB
# Epoch: 486
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7854 dB
# Epoch: 487
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7870 dB
# Epoch: 488
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7852 dB
# Epoch: 489
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7899 dB
# Epoch: 490
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7903 dB
# Epoch: 491
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7875 dB
# Epoch: 492
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7860 dB
# Epoch: 493
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7949 dB
# Epoch: 494
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7955 dB
# Epoch: 495
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7967 dB
# Epoch: 496
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7994 dB
# Epoch: 497
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7876 dB
# Epoch: 498
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.8012 dB
# Epoch: 499
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7993 dB
# Epoch: 500
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.8034 dB
# Checkpoint saved to model_epoch500extend_epoch_500.pth

# %% [markdown]
# ###3.2 Change network architecture
#
# The baseline architecture is as:
#
# ---
# Input Y: H x W x 1
#
# ---
# Conv1 x ReLU:
#
# H x W x 1 --> H x W x 64
#
# ---
# Conv2 x ReLU:
#
# H x W x 64 --> H x W x 64
#
# ---
# Conv3 x ReLU:
#
# H x W x 64 --> H x W x 32
#
# ---
# Conv4:
#
# H x W x 32 --> H x W x (upscale_factor ** 2)
#
# ---
# Pixel_Shuffle:
#
# H x W x (upscale_factor ** 2) --> H' x W' x 1
#
# ---
#
# And the code is as:
#
# ```
# self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
# self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
# self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
# self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
# self.pixel_shuffle = nn.PixelShuffle(upscale_factor)
# ```

# %%
# Net
class Net(nn.Module):
    def __init__(self, upscale_factor):
        super(Net, self).__init__()

        ## Baseline
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
        self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
        self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
        self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
        self.pixel_shuffle = nn.PixelShuffle(upscale_factor)

        ## Code your network below


        self._initialize_weights()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.relu(self.conv3(x))
        x = self.pixel_shuffle(self.conv4(x))
        return x

    def _initialize_weights(self):
        init.orthogonal_(self.conv1.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv2.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv3.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv4.weight)


# Baseline
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)

extendNet_train_errors = []
extendNet_test_psnrs = []

for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    extendNet_train_errors.append(train_error)
    extendNet_test_psnrs.append(test_psnr)
save_checkpoint(args['nEpochs'], model_name='model_extendNet')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# Epoch: 1
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 3.2618
# ===> Test: Avg. PSNR: 6.2649 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.1735
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 13.8151 dB
# Epoch: 3
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0519
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 15.9872 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.0329
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 13.0936 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0370
# ===> Test: Avg. PSNR: 17.0040 dB
# Epoch: 6
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0240
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 17.0027 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0190
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 16.5300 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0198
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 17.5345 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0177
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 17.8555 dB
# Epoch: 10
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0152
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 17.8309 dB
# Epoch: 11
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0154
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 18.2761 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0139
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 18.7203 dB
# Epoch: 13
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0133
# ===> Test: Avg. PSNR: 18.9706 dB
# Epoch: 14
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0123
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.0514 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0124
# ===> Test: Avg. PSNR: 19.1506 dB
# Epoch: 16
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0111
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.2224 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0121
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.3097 dB
# Epoch: 18
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0111
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.3839 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0105
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.4387 dB
# Epoch: 20
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0104
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.4659 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0107
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.5124 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0111
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.5567 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0103
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.5911 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0101
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.6220 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0109
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.6679 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0099
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.7059 dB
# Epoch: 27
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.7524 dB
# Epoch: 28
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0105
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.7959 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0106
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.8353 dB
# Epoch: 30
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 19.8793 dB
# Epoch: 31
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0100
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.9209 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0097
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 19.9636 dB
# Epoch: 33
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0101
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.0022 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0093
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.0436 dB
# Epoch: 35
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0097
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.0928 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0098
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.1268 dB
# Epoch: 37
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0093
# ===> Test: Avg. PSNR: 20.1524 dB
# Epoch: 38
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0085
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.2157 dB
# Epoch: 39
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0090
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.2560 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0091
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.2960 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0088
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.3417 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0090
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.3936 dB
# Epoch: 43
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0086
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.4291 dB
# Epoch: 44
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0091
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.4766 dB
# Epoch: 45
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0084
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.5232 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0086
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.5592 dB
# Epoch: 47
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0081
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.6073 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0086
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.6355 dB
# Epoch: 49
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.6827 dB
# Epoch: 50
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0083
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.7219 dB
# Epoch: 51
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0076
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.7674 dB
# Epoch: 52
# ===> Train: Avg. Loss: 0.0076
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.8086 dB
# Epoch: 53
# ===> Train: Avg. Loss: 0.0083
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.8314 dB
# Epoch: 54
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.8708 dB
# Epoch: 55
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0077
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.8896 dB
# Epoch: 56
# ===> Train: Avg. Loss: 0.0079
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.9190 dB
# Epoch: 57
# ===> Train: Avg. Loss: 0.0078
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.9563 dB
# Epoch: 58
# ===> Train: Avg. Loss: 0.0076
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 20.9849 dB
# Epoch: 59
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0081
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.0129 dB
# Epoch: 60
# ===> Train: Avg. Loss: 0.0076
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.0379 dB
# Epoch: 61
# ===> Train: Avg. Loss: 0.0072
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.0593 dB
# Epoch: 62
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 21.0957 dB
# Epoch: 63
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0075
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.1187 dB
# Epoch: 64
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0072
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.1444 dB
# Epoch: 65
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0076
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.1705 dB
# Epoch: 66
# ===> Train: Avg. Loss: 0.0076
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.1986 dB
# Epoch: 67
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0068
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.2252 dB
# Epoch: 68
# ===> Train: Avg. Loss: 0.0073
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.2512 dB
# Epoch: 69
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0072
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 21.2699 dB
# Epoch: 70
# ...
#   warnings.warn(
# ===> Test: Avg. PSNR: 23.4237 dB
# Epoch: 478
# ===> Train: Avg. Loss: 0.0035
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.0428 dB
# Epoch: 479
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0027
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 24.2258 dB
# Epoch: 480
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0029
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.1170 dB
# Epoch: 481
# ===> Train: Avg. Loss: 0.0024
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 25.5697 dB
# Epoch: 482
# ===> Train: Avg. Loss: 0.0024
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.2778 dB
# Epoch: 483
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9398 dB
# Epoch: 484
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0022
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.3239 dB
# Epoch: 485
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0024
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.1951 dB
# Epoch: 486
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0022
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.3637 dB
# Epoch: 487
# ===> Train: Avg. Loss: 0.0020
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.3710 dB
# Epoch: 488
# ===> Train: Avg. Loss: 0.0021
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.4298 dB
# Epoch: 489
# ===> Train: Avg. Loss: 0.0021
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.4434 dB
# Epoch: 490
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.4575 dB
# Epoch: 491
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0020
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.4873 dB
# Epoch: 492
# ===> Train: Avg. Loss: 0.0020
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.5147 dB
# Epoch: 493
# ===> Train: Avg. Loss: 0.0021
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.5356 dB
# Epoch: 494
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0020
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.5462 dB
# Epoch: 495
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5591 dB
# Epoch: 496
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0020
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.5666 dB
# Epoch: 497
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5785 dB
# Epoch: 498
# ===> Train: Avg. Loss: 0.0019
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.5880 dB
# Epoch: 499
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Train: Avg. Loss: 0.0020
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.5948 dB
# Epoch: 500
# ===> Train: Avg. Loss: 0.0019
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ===> Test: Avg. PSNR: 26.6030 dB
# Checkpoint saved to model_extendNet_epoch_500.pth

# %% [markdown]
# # References:
#
# PyTorch Examples: https://github.com/pytorch/examples/
#
# Plotting: https://www.pluralsight.com/guides/data-visualization-deep-learning-model-using-matplotlib
#
# Real-Time Single Image and Video Super-Resolution Using an Efficient Sub-Pixel Convolutional Neural Network: https://arxiv.org/pdf/1609.05158.pdf
