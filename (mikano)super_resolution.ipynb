# %% [markdown]
# <a href="https://colab.research.google.com/github/yukanaya24/project-1_cvbasic/blob/mikano/(mikano)super_resolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # On how to train and test a deep neural network for the super-resolution task.
# > Prepared by Man M. Ho

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/Lectures/Computer Vision/ch7 image super resolution
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Lectures/Computer Vision/ch7 image super resolution'
# /content

# %% [markdown]
# # Import Libraries

# %%
# For Path Processing
from os.path import exists, join, basename
from os import makedirs, remove, getcwd, listdir

# To download and extract datasets
from six.moves import urllib
import tarfile

# For Datasets and Transformation
from PIL import Image
import torch.utils.data as data
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, ToTensor, Resize

# For Network Architecture
import torch
import torch.nn as nn
import torch.nn.init as init

# PyTorch Optimizer
import torch.optim as optim

# Others
import numpy as np
from math import log10
import matplotlib.pyplot as plt # For plotting

# %% [markdown]
# # Data Preparation and Dataset
#
# Here is the Python code for downloading and extracting the dataset.

# %%
def download_bsds300(dest="dataset"):
    current_dir = getcwd()
    output_image_dir = join(current_dir, dest, "BSDS300/images")

    if not exists(output_image_dir):
        makedirs(dest)
        url = "http://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300-images.tgz"
        print("Downloading Dataset at ", url)

        data = urllib.request.urlopen(url)

        file_path = join(dest, basename(url))
        with open(file_path, 'wb') as f:
            f.write(data.read())

        print("Extracting Data")
        with tarfile.open(file_path) as tar:
            for item in tar:
                tar.extract(item, dest)

        remove(file_path)
    print('Done! Extracted Dataset is saved at : ' + join(output_image_dir))

# %%
download_bsds300()
# Out:
# Done! Extracted Dataset is saved at : /content/dataset/BSDS300/images

# %% [markdown]
# Now we have downloaded the dataset, let's prepare for the dataloader!

# %%
# Check whether your file ends with the exts ".png", ".jpg", and ".jpeg".
def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg"])

# Load image using PIL.Image and convert RGB to YCbCr,
# where: Y is luma/gray component, Cb and CR are chroma/color components.
# In this work, we only up-sample the Y.
def load_img(filepath):
    img = Image.open(filepath).convert('YCbCr')
    y, _, _ = img.split()
    return y

class DatasetFromFolder(data.Dataset):
    def __init__(self, image_dir, input_transform=None, target_transform=None):
        super(DatasetFromFolder, self).__init__()
        self.image_filenames = [join(image_dir, x) for x in listdir(image_dir) if is_image_file(x)]

        self.input_transform = input_transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        # Load Images
        input = load_img(self.image_filenames[index])
        target = input.copy()

        # Input is resize 1/scale as described in the function input_transform
        if self.input_transform:
            input = self.input_transform(input)
        # Target is the original image
        if self.target_transform:
            target = self.target_transform(target)

        return input, target

    def __len__(self):
        return len(self.image_filenames)

# result the suitable crop_size for upscale_factor
def calculate_valid_crop_size(crop_size, upscale_factor):
    return crop_size - (crop_size % upscale_factor)


def input_transform(crop_size, upscale_factor):
    return Compose([
        CenterCrop(crop_size),
        Resize(crop_size // upscale_factor),
        ToTensor(),
    ])


def target_transform(crop_size):
    return Compose([
        CenterCrop(crop_size),
        ToTensor(),
    ])


# This result Pytorch Dataset for training
def get_training_set(root_dir, upscale_factor):
    train_dir = join(root_dir, "train")
    crop_size = calculate_valid_crop_size(256, upscale_factor)

    return DatasetFromFolder(train_dir,
                             input_transform=input_transform(crop_size, upscale_factor),
                             target_transform=target_transform(crop_size))

# This result Pytorch Dataset for testing
def get_test_set(root_dir, upscale_factor):
    test_dir = join(root_dir, "test")
    crop_size = calculate_valid_crop_size(256, upscale_factor)

    return DatasetFromFolder(test_dir,
                             input_transform=input_transform(crop_size, upscale_factor),
                             target_transform=target_transform(crop_size))

# %% [markdown]
# # Network Architecture
# ![Screenshot_308.png](data:image/png;base64,...)

# %% [markdown]
# Regarding the network architecture, we utilize Efficient Sub-Pixel Convolutional Neural Network (ESPCN, https://arxiv.org/pdf/1609.05158.pdf
# ) with N convolutional layers (they set N=4 in the code), the feature size in the inference order are as:
#
# ---
# Input Y: H x W x 1
#
# ---
# Conv1 x ReLU:
#
# H x W x 1 --> H x W x 64
#
# ---
# Conv2 x ReLU:
#
# H x W x 64 --> H x W x 64
#
# ---
# Conv3 x ReLU:
#
# H x W x 64 --> H x W x 32
#
# ---
# Conv4:
#
# H x W x 32 --> H x W x (upscale_factor ** 2)
#
# ---
# Pixel_Shuffle:
#
# H x W x (upscale_factor ** 2) --> H' x W' x 1
#
# where:
#
# H' = H * upscale_factor
#
# W' = W * upscale_factor
#
# Pixel shuffle technique converts a feature map of H x W x (upscale_factor**2) to the high-resolution output image H' x W' x 1
#
# ---
# A code for the network is as:

# %%
class Net(nn.Module):
    def __init__(self, upscale_factor):
        super(Net, self).__init__()

        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
        self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
        self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
        self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
        self.pixel_shuffle = nn.PixelShuffle(upscale_factor)

        self._initialize_weights()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.relu(self.conv3(x))
        x = self.pixel_shuffle(self.conv4(x))
        return x

    def _initialize_weights(self):
        init.orthogonal_(self.conv1.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv2.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv3.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv4.weight)

# %% [markdown]
# # Train Models

# %% [markdown]
# ## Set hyperparameters

# %%
args = {}
# here is where BSD300 dataset is saved
args['root_dir'] = './dataset/BSDS300/images'
# super resolution upscale factor
args['upscale_factor'] = 2
# training batch size
args['batchSize'] = 64
# testing batch size
args['testBatchSize'] = 10
# number of epochs to train for
args['nEpochs'] = 50
# Learning Rate
args['lr'] = 0.01
# number of threads for data loader to use
args['threads'] = 4
# random seed to use
args['seed'] = 42

# %% [markdown]
# ## This keeps your random function consistent for every run so that you can reproduce your results.

# %%
torch.manual_seed(args['seed'])

# %% [markdown]
# ## Declare training and test dataloader

# %%
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# ## Declare model and criteria

# %%
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()

# %% [markdown]
# ## Declare optimizer
#
# Adam: https://arxiv.org/abs/1412.6980

# %%
optimizer = optim.Adam(model.parameters(), lr=args['lr'])

# %% [markdown]
# ## Training function

# %%
def train(epoch):
    print('Epoch: {}'.format(epoch))
    epoch_loss = 0
    for iteration, batch in enumerate(training_data_loader, 1):
        input, target = batch[0].cuda(), batch[1].cuda()

        optimizer.zero_grad()
        loss = training_loss_fn(model(input), target)
        epoch_loss += loss.item()
        loss.backward()
        optimizer.step()

        # print("===> Epoch[{}]({}/{}): Loss: {:.4f}".format(epoch, iteration, len(training_data_loader), loss.item()))

    print("===> Train: Avg. Loss: {:.4f}".format(epoch_loss / len(training_data_loader)))
    return epoch_loss / len(training_data_loader)

# %% [markdown]
# ## Test function

# %%
def test():
    avg_psnr = 0
    with torch.no_grad():
        for batch in testing_data_loader:
            input, target = batch[0].cuda(), batch[1].cuda()

            prediction = model(input)
            mse = mse_fn(prediction, target)
            psnr = 10 * log10(1 / mse.item())
            avg_psnr += psnr
    print("===> Test: Avg. PSNR: {:.4f} dB".format(avg_psnr / len(testing_data_loader)))
    return avg_psnr / len(testing_data_loader)

# %% [markdown]
# ## Save checkpoint

# %%
def save_checkpoint(epoch, model_name='model'):
    model_out_path = model_name + "_epoch_{}.pth".format(epoch)
    torch.save(model, model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))

# %% [markdown]
# ## Train models

# %% [markdown]
# We are using BSDS300 dataset, MSE for the loss function, and a network architecture with 4 convolutional layers.

# %%
base_train_errors = []
base_test_psnrs = []
for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    base_train_errors.append(train_error)
    base_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_base')

# Plotting errors
## Note for plot function, Args from left to right:
### range,
### list of values,
### color such as 'g' -> green, 'b' --> blue, 'r' --> red
#### See more colors here https://matplotlib.org/stable/gallery/color/named_colors.html
### label
plt.figure()
plt.plot(range(1, args['nEpochs'] + 1), base_train_errors, 'g', label='Base Model')
# plt.plot(range(1, args['nEpochs'] + 1), bsds500_train_errors, 'b', label='BSDS500 Model') # You can add another model like this
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

plt.figure()
plt.plot(range(1, args['nEpochs'] + 1), base_test_psnrs, 'g', label='Base Model')
# plt.plot(range(1, args['nEpochs'] + 1), bsds500_test_psnrs, 'b', label='Base Model')# You can add another model like this
plt.title('Val PSNR')
plt.xlabel('Epoch')
plt.ylabel('PSNR')
plt.legend()
plt.show()
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 3.1272
# ===> Test: Avg. PSNR: 6.1232 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.1985
# ===> Test: Avg. PSNR: 10.1082 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.0643
# ===> Test: Avg. PSNR: 12.4894 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.0334
# ===> Test: Avg. PSNR: 13.5093 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0415
# ===> Test: Avg. PSNR: 15.6484 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0244
# ===> Test: Avg. PSNR: 14.9620 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0223
# ===> Test: Avg. PSNR: 16.5241 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0198
# ===> Test: Avg. PSNR: 17.4601 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0170
# ===> Test: Avg. PSNR: 18.0325 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0140
# ===> Test: Avg. PSNR: 18.8265 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0120
# ===> Test: Avg. PSNR: 19.0916 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0121
# ===> Test: Avg. PSNR: 19.4713 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.6048 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0098
# ===> Test: Avg. PSNR: 19.7273 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.8440 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0100
# ===> Test: Avg. PSNR: 19.8901 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0096
# ===> Test: Avg. PSNR: 19.9852 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 20.0355 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 20.1079 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.1619 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0087
# ===> Test: Avg. PSNR: 20.2000 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0094
# ===> Test: Avg. PSNR: 20.2405 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0085
# ===> Test: Avg. PSNR: 20.2956 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.3438 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 20.3597 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.3953 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0088
# ===> Test: Avg. PSNR: 20.4797 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0087
# ===> Test: Avg. PSNR: 20.5129 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.5438 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.5986 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.6243 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.6591 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0081
# ===> Test: Avg. PSNR: 20.7110 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.7430 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.7733 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.8172 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.8518 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.8887 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 20.9206 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 20.9471 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0080
# ===> Test: Avg. PSNR: 20.9844 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.0154 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 21.0287 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0073
# ===> Test: Avg. PSNR: 21.0901 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 21.0875 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.1543 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0077
# ===> Test: Avg. PSNR: 21.1839 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0067
# ===> Test: Avg. PSNR: 21.1979 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 21.2464 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.2776 dB
# Checkpoint saved to model_base_epoch_50.pth

# %% [markdown]
# # Tasks
# Task 1.学習済みモデルを用いて、1枚の画像に対するテスト結果を確認する（20点）
#
# Task 2.損失関数に関するアブレーションスタディを実施する。各損失関数を用いた際のモデル性能（PSNR）を比較する。（30点）
#
# Task 3.ネットワーク構造やハイパーパラメータなどを調整し、性能（PSNR）の向上を図る（50点）
#
# 上記に示したトレーニング損失や検証時のPSNRのプロット方法を参考にしてください。

# %% [markdown]
# ##Task 1. Test the trained model on your own images
#
# The run function is as:

# %%
def run_model(input_image, output_filename, model_path):
  img = Image.open(input_image).convert('YCbCr')
  y, cb, cr = img.split()

  model = torch.load(model_path, weights_only=False)
  img_to_tensor = ToTensor()
  input = img_to_tensor(y).view(1, -1, y.size[1], y.size[0])

  model = model.cuda()
  input = input.cuda()

  out = model(input)
  out = out.cpu()
  out_img_y = out[0].detach().numpy()
  out_img_y *= 255.0
  out_img_y = out_img_y.clip(0, 255)
  out_img_y = Image.fromarray(np.uint8(out_img_y[0]), mode='L')

  out_img_cb = cb.resize(out_img_y.size, Image.BICUBIC)
  out_img_cr = cr.resize(out_img_y.size, Image.BICUBIC)
  out_img = Image.merge('YCbCr', [out_img_y, out_img_cb, out_img_cr]).convert('RGB')

  out_img.save(output_filename)
  print('Output image saved to ', output_filename)
  return img.convert('RGB'), out_img

# %%
# An example
input_image = "./dataset/BSDS300/images/test/101085.jpg"
output_filename = "101085_x2.jpg"

model_path = "model_base_epoch_50.pth"
img, out_img = run_model(input_image, output_filename, model_path)
# Out:
# Output image saved to  101085_x2.jpg

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=321x481>

# %%
out_img
# Out:
# <PIL.Image.Image image mode=RGB size=642x962>

# %% [markdown]
# ##Task 2. Conduct an ablation study on loss function.
#
# MSE（Mean Square Error：平均二乗誤差）以外にも、画像生成に用いられる損失関数は多数存在します。以下はその一部です：
#
# L1: https://pytorch.org/docs/stable/generated/torch.nn.L1Loss.html#torch.nn.L1Loss
#
# L1 Smooth: https://pytorch.org/docs/stable/generated/torch.nn.SmoothL1Loss.html#torch.nn.SmoothL1Loss
#
# Huber Loss: https://pytorch.org/docs/stable/generated/torch.nn.HuberLoss.html#torch.nn.HuberLoss
#
# MS-SSIM: https://github.com/jorge-pessoa/pytorch-msssim
#
# LPIPS: https://github.com/richzhang/PerceptualSimilarity
#
# MSE以外の損失関数に変更し、結果を分析してください。
# 以下はL1損失関数に変更する例です。

# %%
# Baseline, training_loss_fn is commented for changing
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
# training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)

# Change the Training Loss Function
training_loss_fn = nn.L1Loss()

l1loss_train_errors = []
l1loss_test_psnrs = []

for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    l1loss_train_errors.append(train_error)
    l1loss_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_l1loss')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 1.5605
# ===> Test: Avg. PSNR: 6.8913 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.3192
# ===> Test: Avg. PSNR: 10.0454 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.1804
# ===> Test: Avg. PSNR: 14.2092 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.1456
# ===> Test: Avg. PSNR: 14.2081 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.1050
# ===> Test: Avg. PSNR: 18.1586 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0946
# ===> Test: Avg. PSNR: 18.5276 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0886
# ===> Test: Avg. PSNR: 17.5407 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0821
# ===> Test: Avg. PSNR: 18.8558 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0822
# ===> Test: Avg. PSNR: 19.0308 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0727
# ===> Test: Avg. PSNR: 20.6814 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0629
# ===> Test: Avg. PSNR: 20.6778 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0614
# ===> Test: Avg. PSNR: 21.0130 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0677
# ===> Test: Avg. PSNR: 17.4388 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0795
# ===> Test: Avg. PSNR: 21.0395 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0630
# ===> Test: Avg. PSNR: 20.9508 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0589
# ===> Test: Avg. PSNR: 21.2908 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0539
# ===> Test: Avg. PSNR: 21.4505 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0541
# ===> Test: Avg. PSNR: 21.7369 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0565
# ===> Test: Avg. PSNR: 21.4779 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0542
# ===> Test: Avg. PSNR: 22.0310 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0540
# ===> Test: Avg. PSNR: 22.1636 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0542
# ===> Test: Avg. PSNR: 21.4333 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0531
# ===> Test: Avg. PSNR: 21.5239 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0500
# ===> Test: Avg. PSNR: 22.0482 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0511
# ===> Test: Avg. PSNR: 22.2360 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0447
# ===> Test: Avg. PSNR: 21.6912 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0539
# ===> Test: Avg. PSNR: 20.6652 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0613
# ===> Test: Avg. PSNR: 22.2117 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0491
# ===> Test: Avg. PSNR: 22.2095 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0472
# ===> Test: Avg. PSNR: 22.0866 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0455
# ===> Test: Avg. PSNR: 22.6855 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0433
# ===> Test: Avg. PSNR: 22.8246 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0433
# ===> Test: Avg. PSNR: 22.8993 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0422
# ===> Test: Avg. PSNR: 22.5259 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0455
# ===> Test: Avg. PSNR: 22.9440 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0427
# ===> Test: Avg. PSNR: 22.0896 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0479
# ===> Test: Avg. PSNR: 21.8235 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0535
# ===> Test: Avg. PSNR: 22.2291 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0511
# ===> Test: Avg. PSNR: 23.0557 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0453
# ===> Test: Avg. PSNR: 23.3027 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0436
# ===> Test: Avg. PSNR: 23.2001 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0421
# ===> Test: Avg. PSNR: 23.6200 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0428
# ===> Test: Avg. PSNR: 23.1188 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0437
# ===> Test: Avg. PSNR: 21.6946 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0530
# ===> Test: Avg. PSNR: 23.5598 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0427
# ===> Test: Avg. PSNR: 23.6993 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0402
# ===> Test: Avg. PSNR: 23.7815 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0367
# ===> Test: Avg. PSNR: 24.0129 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0360
# ===> Test: Avg. PSNR: 24.0286 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0351
# ===> Test: Avg. PSNR: 24.0122 dB
# Checkpoint saved to model_l1loss_epoch_50.pth

# %% [markdown]
# ##Task 3 Optimization

# %% [markdown]
# ###3.1 Modify hyper parameters

# %%
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)



args['nEpochs'] = 500

epoch500extend_train_errors = []
epoch500extend_test_psnrs = []

for epoch in range(1, args['nEpochs']  + 1):
    train_error = train(epoch)
    test_psnr = test()
    epoch500extend_train_errors.append(train_error)
    epoch500extend_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_epoch500extend')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 3.1272
# ===> Test: Avg. PSNR: 6.1232 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.1985
# ===> Test: Avg. PSNR: 10.1082 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.0643
# ===> Test: Avg. PSNR: 12.4894 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.0334
# ===> Test: Avg. PSNR: 13.5093 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0415
# ===> Test: Avg. PSNR: 15.6484 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0244
# ===> Test: Avg. PSNR: 14.9620 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0223
# ===> Test: Avg. PSNR: 16.5241 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0198
# ===> Test: Avg. PSNR: 17.4601 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0170
# ===> Test: Avg. PSNR: 18.0325 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0140
# ===> Test: Avg. PSNR: 18.8265 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0120
# ===> Test: Avg. PSNR: 19.0916 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0121
# ===> Test: Avg. PSNR: 19.4713 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.6048 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0098
# ===> Test: Avg. PSNR: 19.7273 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.8440 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0100
# ===> Test: Avg. PSNR: 19.8901 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0096
# ===> Test: Avg. PSNR: 19.9852 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 20.0355 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 20.1079 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.1619 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0087
# ===> Test: Avg. PSNR: 20.2000 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0094
# ===> Test: Avg. PSNR: 20.2405 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0085
# ===> Test: Avg. PSNR: 20.2956 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.3438 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 20.3597 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.3953 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0088
# ===> Test: Avg. PSNR: 20.4797 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0087
# ===> Test: Avg. PSNR: 20.5129 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.5438 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.5986 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.6243 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.6591 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0081
# ===> Test: Avg. PSNR: 20.7110 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.7430 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.7733 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.8172 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.8518 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.8887 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 20.9206 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 20.9471 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0080
# ===> Test: Avg. PSNR: 20.9844 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.0154 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 21.0287 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0073
# ===> Test: Avg. PSNR: 21.0901 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 21.0875 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.1543 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0077
# ===> Test: Avg. PSNR: 21.1839 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0067
# ===> Test: Avg. PSNR: 21.1979 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 21.2464 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.2776 dB
# Epoch: 51
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.2978 dB
# Epoch: 52
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.3355 dB
# Epoch: 53
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.3629 dB
# Epoch: 54
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 21.3906 dB
# Epoch: 55
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.4154 dB
# Epoch: 56
# ===> Train: Avg. Loss: 0.0072
# ===> Test: Avg. PSNR: 21.4462 dB
# Epoch: 57
# ===> Train: Avg. Loss: 0.0067
# ===> Test: Avg. PSNR: 21.4739 dB
# Epoch: 58
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.5027 dB
# Epoch: 59
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.5307 dB
# Epoch: 60
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.5585 dB
# Epoch: 61
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.5721 dB
# Epoch: 62
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.5932 dB
# Epoch: 63
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.6402 dB
# Epoch: 64
# ===> Train: Avg. Loss: 0.0062
# ===> Test: Avg. PSNR: 21.6625 dB
# Epoch: 65
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.6677 dB
# Epoch: 66
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.6955 dB
# Epoch: 67
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.7382 dB
# Epoch: 68
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.7715 dB
# Epoch: 69
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.7897 dB
# Epoch: 70
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.8188 dB
# Epoch: 71
# ===> Train: Avg. Loss: 0.0060
# ===> Test: Avg. PSNR: 21.8513 dB
# Epoch: 72
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.8661 dB
# Epoch: 73
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.8758 dB
# Epoch: 74
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.9068 dB
# Epoch: 75
# ===> Train: Avg. Loss: 0.0061
# ===> Test: Avg. PSNR: 21.9932 dB
# Epoch: 76
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 22.0486 dB
# Epoch: 77
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 22.0810 dB
# Epoch: 78
# ===> Train: Avg. Loss: 0.0062
# ===> Test: Avg. PSNR: 22.1149 dB
# Epoch: 79
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 22.1390 dB
# Epoch: 80
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 22.1699 dB
# Epoch: 81
# ===> Train: Avg. Loss: 0.0054
# ===> Test: Avg. PSNR: 22.2036 dB
# Epoch: 82
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.2331 dB
# Epoch: 83
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.2581 dB
# Epoch: 84
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 22.3079 dB
# Epoch: 85
# ===> Train: Avg. Loss: 0.0056
# ===> Test: Avg. PSNR: 22.3380 dB
# Epoch: 86
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.3672 dB
# Epoch: 87
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.3957 dB
# Epoch: 88
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 22.4186 dB
# Epoch: 89
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 22.4487 dB
# Epoch: 90
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.4711 dB
# Epoch: 91
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.5124 dB
# Epoch: 92
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.5371 dB
# Epoch: 93
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.5705 dB
# Epoch: 94
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.5931 dB
# Epoch: 95
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.6089 dB
# Epoch: 96
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 22.6524 dB
# Epoch: 97
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.6776 dB
# Epoch: 98
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.7089 dB
# Epoch: 99
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.7215 dB
# Epoch: 100
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.7573 dB
# Epoch: 101
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.7698 dB
# Epoch: 102
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.8022 dB
# Epoch: 103
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.8425 dB
# Epoch: 104
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 22.8689 dB
# Epoch: 105
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.8873 dB
# Epoch: 106
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 22.9205 dB
# Epoch: 107
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.9467 dB
# Epoch: 108
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 22.9580 dB
# Epoch: 109
# ===> Train: Avg. Loss: 0.0049
# ===> Test: Avg. PSNR: 22.9955 dB
# Epoch: 110
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.0191 dB
# Epoch: 111
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 23.0409 dB
# Epoch: 112
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 23.0457 dB
# Epoch: 113
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.0903 dB
# Epoch: 114
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 23.0616 dB
# Epoch: 115
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.1427 dB
# Epoch: 116
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.0994 dB
# Epoch: 117
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.1895 dB
# Epoch: 118
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.1719 dB
# Epoch: 119
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.2276 dB
# Epoch: 120
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.1772 dB
# Epoch: 121
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.2796 dB
# Epoch: 122
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.2800 dB
# Epoch: 123
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.3253 dB
# Epoch: 124
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.3206 dB
# Epoch: 125
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.3674 dB
# Epoch: 126
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.3839 dB
# Epoch: 127
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.3930 dB
# Epoch: 128
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.4298 dB
# Epoch: 129
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.4492 dB
# Epoch: 130
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.4702 dB
# Epoch: 131
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.4701 dB
# Epoch: 132
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.5133 dB
# Epoch: 133
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.5282 dB
# Epoch: 134
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.5416 dB
# Epoch: 135
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.5597 dB
# Epoch: 136
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.5954 dB
# Epoch: 137
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6158 dB
# Epoch: 138
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6335 dB
# Epoch: 139
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6545 dB
# Epoch: 140
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.6630 dB
# Epoch: 141
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.6410 dB
# Epoch: 142
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6813 dB
# Epoch: 143
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.6929 dB
# Epoch: 144
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.6948 dB
# Epoch: 145
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.7507 dB
# Epoch: 146
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.7406 dB
# Epoch: 147
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.8020 dB
# Epoch: 148
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.8133 dB
# Epoch: 149
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.8386 dB
# Epoch: 150
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.8531 dB
# Epoch: 151
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.8546 dB
# Epoch: 152
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.8771 dB
# Epoch: 153
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.9110 dB
# Epoch: 154
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 23.8785 dB
# Epoch: 155
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.9279 dB
# Epoch: 156
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.9567 dB
# Epoch: 157
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.9798 dB
# Epoch: 158
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.9973 dB
# Epoch: 159
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 24.0006 dB
# Epoch: 160
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 24.0018 dB
# Epoch: 161
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 24.0495 dB
# Epoch: 162
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.9338 dB
# Epoch: 163
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 24.0699 dB
# Epoch: 164
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.1096 dB
# Epoch: 165
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 21.3438 dB
# Epoch: 166
# ===> Train: Avg. Loss: 0.0060
# ===> Test: Avg. PSNR: 17.9972 dB
# Epoch: 167
# ===> Train: Avg. Loss: 0.0132
# ===> Test: Avg. PSNR: 19.5065 dB
# Epoch: 168
# ===> Train: Avg. Loss: 0.0089
# ===> Test: Avg. PSNR: 20.7318 dB
# Epoch: 169
# ===> Train: Avg. Loss: 0.0070
# ===> Test: Avg. PSNR: 20.0853 dB
# Epoch: 170
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 20.8559 dB
# Epoch: 171
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 22.5789 dB
# Epoch: 172
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 24.0009 dB
# Epoch: 173
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.6597 dB
# Epoch: 174
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.4988 dB
# Epoch: 175
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.8632 dB
# Epoch: 176
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.0841 dB
# Epoch: 177
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.9687 dB
# Epoch: 178
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 23.8897 dB
# Epoch: 179
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.0331 dB
# Epoch: 180
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.1738 dB
# Epoch: 181
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.1651 dB
# Epoch: 182
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.1868 dB
# Epoch: 183
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 24.2180 dB
# Epoch: 184
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.2374 dB
# Epoch: 185
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.2535 dB
# Epoch: 186
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 24.2685 dB
# Epoch: 187
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.2827 dB
# Epoch: 188
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.2988 dB
# Epoch: 189
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.3087 dB
# Epoch: 190
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.3180 dB
# Epoch: 191
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 24.3312 dB
# Epoch: 192
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.3414 dB
# Epoch: 193
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.3516 dB
# Epoch: 194
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.3842 dB
# Epoch: 195
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.3987 dB
# Epoch: 196
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.4031 dB
# Epoch: 197
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.4090 dB
# Epoch: 198
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.4300 dB
# Epoch: 199
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.4375 dB
# Epoch: 200
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.4515 dB
# Epoch: 201
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.4670 dB
# Epoch: 202
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.4806 dB
# Epoch: 203
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.5012 dB
# Epoch: 204
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.5147 dB
# Epoch: 205
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.5336 dB
# Epoch: 206
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.5461 dB
# Epoch: 207
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.5586 dB
# Epoch: 208
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.5690 dB
# Epoch: 209
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.5854 dB
# Epoch: 210
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.5990 dB
# Epoch: 211
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.6127 dB
# Epoch: 212
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.6251 dB
# Epoch: 213
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.6365 dB
# Epoch: 214
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.6512 dB
# Epoch: 215
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.6649 dB
# Epoch: 216
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.6778 dB
# Epoch: 217
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.6912 dB
# Epoch: 218
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.6977 dB
# Epoch: 219
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.7152 dB
# Epoch: 220
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.7279 dB
# Epoch: 221
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.7419 dB
# Epoch: 222
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.7411 dB
# Epoch: 223
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.7634 dB
# Epoch: 224
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.7551 dB
# Epoch: 225
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.7810 dB
# Epoch: 226
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.8031 dB
# Epoch: 227
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 24.8172 dB
# Epoch: 228
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.8291 dB
# Epoch: 229
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.8405 dB
# Epoch: 230
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.8494 dB
# Epoch: 231
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.8651 dB
# Epoch: 232
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.8728 dB
# Epoch: 233
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.8862 dB
# Epoch: 234
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9004 dB
# Epoch: 235
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.9069 dB
# Epoch: 236
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9234 dB
# Epoch: 237
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.9313 dB
# Epoch: 238
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.9485 dB
# Epoch: 239
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.9601 dB
# Epoch: 240
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9658 dB
# Epoch: 241
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9628 dB
# Epoch: 242
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.9888 dB
# Epoch: 243
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.0062 dB
# Epoch: 244
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 25.0157 dB
# Epoch: 245
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.0137 dB
# Epoch: 246
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.0279 dB
# Epoch: 247
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.0508 dB
# Epoch: 248
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.0621 dB
# Epoch: 249
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.0699 dB
# Epoch: 250
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.0841 dB
# Epoch: 251
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.0948 dB
# Epoch: 252
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 25.1031 dB
# Epoch: 253
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.1083 dB
# Epoch: 254
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.1242 dB
# Epoch: 255
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.1121 dB
# Epoch: 256
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 25.1403 dB
# Epoch: 257
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.1571 dB
# Epoch: 258
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.1555 dB
# Epoch: 259
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.1781 dB
# Epoch: 260
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.1868 dB
# Epoch: 261
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.1923 dB
# Epoch: 262
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2080 dB
# Epoch: 263
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 25.2170 dB
# Epoch: 264
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.2292 dB
# Epoch: 265
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2310 dB
# Epoch: 266
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.2467 dB
# Epoch: 267
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.2579 dB
# Epoch: 268
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2629 dB
# Epoch: 269
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2731 dB
# Epoch: 270
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2738 dB
# Epoch: 271
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2682 dB
# Epoch: 272
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2926 dB
# Epoch: 273
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.3095 dB
# Epoch: 274
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3184 dB
# Epoch: 275
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3322 dB
# Epoch: 276
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.3281 dB
# Epoch: 277
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.3476 dB
# Epoch: 278
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.3507 dB
# Epoch: 279
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3658 dB
# Epoch: 280
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3635 dB
# Epoch: 281
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3841 dB
# Epoch: 282
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.3883 dB
# Epoch: 283
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.3962 dB
# Epoch: 284
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4104 dB
# Epoch: 285
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4149 dB
# Epoch: 286
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4256 dB
# Epoch: 287
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4263 dB
# Epoch: 288
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4428 dB
# Epoch: 289
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.4490 dB
# Epoch: 290
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4595 dB
# Epoch: 291
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.4670 dB
# Epoch: 292
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.4765 dB
# Epoch: 293
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.4791 dB
# Epoch: 294
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4906 dB
# Epoch: 295
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4918 dB
# Epoch: 296
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.4993 dB
# Epoch: 297
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4816 dB
# Epoch: 298
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5123 dB
# Epoch: 299
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5101 dB
# Epoch: 300
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.5335 dB
# Epoch: 301
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5412 dB
# Epoch: 302
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5476 dB
# Epoch: 303
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5641 dB
# Epoch: 304
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.5715 dB
# Epoch: 305
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5796 dB
# Epoch: 306
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5871 dB
# Epoch: 307
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5909 dB
# Epoch: 308
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.5783 dB
# Epoch: 309
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6093 dB
# Epoch: 310
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6115 dB
# Epoch: 311
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6246 dB
# Epoch: 312
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.6303 dB
# Epoch: 313
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6352 dB
# Epoch: 314
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6418 dB
# Epoch: 315
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6526 dB
# Epoch: 316
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6573 dB
# Epoch: 317
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6665 dB
# Epoch: 318
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6774 dB
# Epoch: 319
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6709 dB
# Epoch: 320
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6752 dB
# Epoch: 321
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6946 dB
# Epoch: 322
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.7037 dB
# Epoch: 323
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7143 dB
# Epoch: 324
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7146 dB
# Epoch: 325
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.7251 dB
# Epoch: 326
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7341 dB
# Epoch: 327
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.7262 dB
# Epoch: 328
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7380 dB
# Epoch: 329
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7551 dB
# Epoch: 330
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7625 dB
# Epoch: 331
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7705 dB
# Epoch: 332
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7715 dB
# Epoch: 333
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7735 dB
# Epoch: 334
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7922 dB
# Epoch: 335
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.7906 dB
# Epoch: 336
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8066 dB
# Epoch: 337
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.8099 dB
# Epoch: 338
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8117 dB
# Epoch: 339
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8204 dB
# Epoch: 340
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.8333 dB
# Epoch: 341
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8296 dB
# Epoch: 342
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.8474 dB
# Epoch: 343
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8449 dB
# Epoch: 344
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.8538 dB
# Epoch: 345
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8691 dB
# Epoch: 346
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 25.8764 dB
# Epoch: 347
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8795 dB
# Epoch: 348
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8820 dB
# Epoch: 349
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8952 dB
# Epoch: 350
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8962 dB
# Epoch: 351
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9075 dB
# Epoch: 352
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9158 dB
# Epoch: 353
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.9125 dB
# Epoch: 354
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.9286 dB
# Epoch: 355
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9341 dB
# Epoch: 356
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9379 dB
# Epoch: 357
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9438 dB
# Epoch: 358
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9539 dB
# Epoch: 359
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.9602 dB
# Epoch: 360
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 25.9669 dB
# Epoch: 361
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9727 dB
# Epoch: 362
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9773 dB
# Epoch: 363
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9843 dB
# Epoch: 364
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9910 dB
# Epoch: 365
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9975 dB
# Epoch: 366
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0035 dB
# Epoch: 367
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0088 dB
# Epoch: 368
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0149 dB
# Epoch: 369
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0209 dB
# Epoch: 370
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0256 dB
# Epoch: 371
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0281 dB
# Epoch: 372
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0307 dB
# Epoch: 373
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0384 dB
# Epoch: 374
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0360 dB
# Epoch: 375
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.0384 dB
# Epoch: 376
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0504 dB
# Epoch: 377
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0584 dB
# Epoch: 378
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0708 dB
# Epoch: 379
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0776 dB
# Epoch: 380
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0811 dB
# Epoch: 381
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0870 dB
# Epoch: 382
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0872 dB
# Epoch: 383
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0962 dB
# Epoch: 384
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1027 dB
# Epoch: 385
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1093 dB
# Epoch: 386
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1131 dB
# Epoch: 387
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1190 dB
# Epoch: 388
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1179 dB
# Epoch: 389
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1132 dB
# Epoch: 390
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1328 dB
# Epoch: 391
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1401 dB
# Epoch: 392
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1442 dB
# Epoch: 393
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1441 dB
# Epoch: 394
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1355 dB
# Epoch: 395
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1565 dB
# Epoch: 396
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1560 dB
# Epoch: 397
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1523 dB
# Epoch: 398
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0671 dB
# Epoch: 399
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1576 dB
# Epoch: 400
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1488 dB
# Epoch: 401
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1800 dB
# Epoch: 402
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1769 dB
# Epoch: 403
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1949 dB
# Epoch: 404
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2012 dB
# Epoch: 405
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1020 dB
# Epoch: 406
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1933 dB
# Epoch: 407
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 26.2067 dB
# Epoch: 408
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1910 dB
# Epoch: 409
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2236 dB
# Epoch: 410
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2300 dB
# Epoch: 411
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9710 dB
# Epoch: 412
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1718 dB
# Epoch: 413
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2372 dB
# Epoch: 414
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2438 dB
# Epoch: 415
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1820 dB
# Epoch: 416
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.7253 dB
# Epoch: 417
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2221 dB
# Epoch: 418
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2660 dB
# Epoch: 419
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1093 dB
# Epoch: 420
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2279 dB
# Epoch: 421
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2771 dB
# Epoch: 422
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2662 dB
# Epoch: 423
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2300 dB
# Epoch: 424
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2916 dB
# Epoch: 425
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2953 dB
# Epoch: 426
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2677 dB
# Epoch: 427
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1977 dB
# Epoch: 428
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2929 dB
# Epoch: 429
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2982 dB
# Epoch: 430
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0401 dB
# Epoch: 431
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.9224 dB
# Epoch: 432
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 25.6215 dB
# Epoch: 433
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 23.7315 dB
# Epoch: 434
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.6408 dB
# Epoch: 435
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 23.8013 dB
# Epoch: 436
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 25.6969 dB
# Epoch: 437
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 17.1219 dB
# Epoch: 438
# ===> Train: Avg. Loss: 0.0203
# ===> Test: Avg. PSNR: 19.1588 dB
# Epoch: 439
# ===> Train: Avg. Loss: 0.0167
# ===> Test: Avg. PSNR: 16.5708 dB
# Epoch: 440
# ===> Train: Avg. Loss: 0.0182
# ===> Test: Avg. PSNR: 14.9484 dB
# Epoch: 441
# ===> Train: Avg. Loss: 0.0168
# ===> Test: Avg. PSNR: 24.4745 dB
# Epoch: 442
# ===> Train: Avg. Loss: 0.0077
# ===> Test: Avg. PSNR: 18.1942 dB
# Epoch: 443
# ===> Train: Avg. Loss: 0.0103
# ===> Test: Avg. PSNR: 24.4002 dB
# Epoch: 444
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 19.9771 dB
# Epoch: 445
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 23.7539 dB
# Epoch: 446
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.2258 dB
# Epoch: 447
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.8458 dB
# Epoch: 448
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 25.4390 dB
# Epoch: 449
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.5985 dB
# Epoch: 450
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.8505 dB
# Epoch: 451
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5214 dB
# Epoch: 452
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9502 dB
# Epoch: 453
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7954 dB
# Epoch: 454
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0393 dB
# Epoch: 455
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 25.9168 dB
# Epoch: 456
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0880 dB
# Epoch: 457
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0159 dB
# Epoch: 458
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1235 dB
# Epoch: 459
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1002 dB
# Epoch: 460
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1625 dB
# Epoch: 461
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1543 dB
# Epoch: 462
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1889 dB
# Epoch: 463
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2060 dB
# Epoch: 464
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2063 dB
# Epoch: 465
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2319 dB
# Epoch: 466
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2302 dB
# Epoch: 467
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2539 dB
# Epoch: 468
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2583 dB
# Epoch: 469
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2737 dB
# Epoch: 470
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2816 dB
# Epoch: 471
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2907 dB
# Epoch: 472
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2998 dB
# Epoch: 473
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.3074 dB
# Epoch: 474
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3146 dB
# Epoch: 475
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3227 dB
# Epoch: 476
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3294 dB
# Epoch: 477
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3355 dB
# Epoch: 478
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.3418 dB
# Epoch: 479
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3476 dB
# Epoch: 480
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.3531 dB
# Epoch: 481
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3580 dB
# Epoch: 482
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3634 dB
# Epoch: 483
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3681 dB
# Epoch: 484
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3732 dB
# Epoch: 485
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3780 dB
# Epoch: 486
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3824 dB
# Epoch: 487
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3872 dB
# Epoch: 488
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3919 dB
# Epoch: 489
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3959 dB
# Epoch: 490
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.4002 dB
# Epoch: 491
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.4042 dB
# Epoch: 492
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4083 dB
# Epoch: 493
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4121 dB
# Epoch: 494
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4149 dB
# Epoch: 495
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4196 dB
# Epoch: 496
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4234 dB
# Epoch: 497
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4274 dB
# Epoch: 498
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4310 dB
# Epoch: 499
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4342 dB
# Epoch: 500
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4378 dB
# Checkpoint saved to model_epoch500extend_epoch_500.pth

# %% [markdown]
# ###3.2 Change network architecture
#
# The baseline architecture is as:
#
# ---
# Input Y: H x W x 1
#
# ---
# Conv1 x ReLU:
#
# H x W x 1 --> H x W x 64
#
# ---
# Conv2 x ReLU:
#
# H x W x 64 --> H x W x 64
#
# ---
# Conv3 x ReLU:
#
# H x W x 64 --> H x W x 32
#
# ---
# Conv4:
#
# H x W x 32 --> H x W x (upscale_factor ** 2)
#
# ---
# Pixel_Shuffle:
#
# H x W x (upscale_factor ** 2) --> H' x W' x 1
#
# ---
#
# And the code is as:
#
# ```
# self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
# self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
# self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
# self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
# self.pixel_shuffle = nn.PixelShuffle(upscale_factor)
# ```

# %%
# Net
class Net(nn.Module):
    def __init__(self, upscale_factor):
        super(Net, self).__init__()

        ## Baseline
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
        self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
        self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
        self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
        self.pixel_shuffle = nn.PixelShuffle(upscale_factor)

        ## Code your network below


        self._initialize_weights()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.relu(self.conv3(x))
        x = self.pixel_shuffle(self.conv4(x))
        return x

    def _initialize_weights(self):
        init.orthogonal_(self.conv1.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv2.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv3.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv4.weight)


# Baseline
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)

extendNet_train_errors = []
extendNet_test_psnrs = []

for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    extendNet_train_errors.append(train_error)
    extendNet_test_psnrs.append(test_psnr)
save_checkpoint(args['nEpochs'], model_name='model_extendNet')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 3.1272
# ===> Test: Avg. PSNR: 6.1232 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.1985
# ===> Test: Avg. PSNR: 10.1082 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.0643
# ===> Test: Avg. PSNR: 12.4894 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.0334
# ===> Test: Avg. PSNR: 13.5093 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0415
# ===> Test: Avg. PSNR: 15.6484 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0244
# ===> Test: Avg. PSNR: 14.9620 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0223
# ===> Test: Avg. PSNR: 16.5241 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0198
# ===> Test: Avg. PSNR: 17.4601 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0170
# ===> Test: Avg. PSNR: 18.0325 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0140
# ===> Test: Avg. PSNR: 18.8265 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0120
# ===> Test: Avg. PSNR: 19.0916 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0121
# ===> Test: Avg. PSNR: 19.4713 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.6049 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0098
# ===> Test: Avg. PSNR: 19.7273 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.8440 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0100
# ===> Test: Avg. PSNR: 19.8901 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0096
# ===> Test: Avg. PSNR: 19.9852 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 20.0355 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 20.1079 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0086
# ===> Test: Avg. PSNR: 20.1619 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0087
# ===> Test: Avg. PSNR: 20.2000 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0094
# ===> Test: Avg. PSNR: 20.2405 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0085
# ===> Test: Avg. PSNR: 20.2956 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.3438 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 20.3597 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.3953 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0088
# ===> Test: Avg. PSNR: 20.4797 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0087
# ===> Test: Avg. PSNR: 20.5129 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.5438 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.5986 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.6243 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.6591 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0081
# ===> Test: Avg. PSNR: 20.7110 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.7430 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0079
# ===> Test: Avg. PSNR: 20.7733 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.8172 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 20.8518 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 20.8887 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 20.9206 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 20.9471 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0080
# ===> Test: Avg. PSNR: 20.9844 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.0154 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0078
# ===> Test: Avg. PSNR: 21.0287 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0073
# ===> Test: Avg. PSNR: 21.0900 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 21.0875 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.1542 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0077
# ===> Test: Avg. PSNR: 21.1839 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0067
# ===> Test: Avg. PSNR: 21.1979 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 21.2464 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.2776 dB
# Epoch: 51
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.2978 dB
# Epoch: 52
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.3355 dB
# Epoch: 53
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.3629 dB
# Epoch: 54
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 21.3906 dB
# Epoch: 55
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.4154 dB
# Epoch: 56
# ===> Train: Avg. Loss: 0.0072
# ===> Test: Avg. PSNR: 21.4462 dB
# Epoch: 57
# ===> Train: Avg. Loss: 0.0067
# ===> Test: Avg. PSNR: 21.4739 dB
# Epoch: 58
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.5027 dB
# Epoch: 59
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.5307 dB
# Epoch: 60
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.5585 dB
# Epoch: 61
# ===> Train: Avg. Loss: 0.0071
# ===> Test: Avg. PSNR: 21.5721 dB
# Epoch: 62
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.5932 dB
# Epoch: 63
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.6402 dB
# Epoch: 64
# ===> Train: Avg. Loss: 0.0062
# ===> Test: Avg. PSNR: 21.6624 dB
# Epoch: 65
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.6677 dB
# Epoch: 66
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.6955 dB
# Epoch: 67
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.7381 dB
# Epoch: 68
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.7715 dB
# Epoch: 69
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.7897 dB
# Epoch: 70
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.8188 dB
# Epoch: 71
# ===> Train: Avg. Loss: 0.0060
# ===> Test: Avg. PSNR: 21.8513 dB
# Epoch: 72
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.8661 dB
# Epoch: 73
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.8758 dB
# Epoch: 74
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.9068 dB
# Epoch: 75
# ===> Train: Avg. Loss: 0.0061
# ===> Test: Avg. PSNR: 21.9932 dB
# Epoch: 76
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 22.0486 dB
# Epoch: 77
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 22.0810 dB
# Epoch: 78
# ===> Train: Avg. Loss: 0.0062
# ===> Test: Avg. PSNR: 22.1149 dB
# Epoch: 79
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 22.1390 dB
# Epoch: 80
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 22.1698 dB
# Epoch: 81
# ===> Train: Avg. Loss: 0.0054
# ===> Test: Avg. PSNR: 22.2036 dB
# Epoch: 82
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.2330 dB
# Epoch: 83
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.2581 dB
# Epoch: 84
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 22.3079 dB
# Epoch: 85
# ===> Train: Avg. Loss: 0.0056
# ===> Test: Avg. PSNR: 22.3380 dB
# Epoch: 86
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.3672 dB
# Epoch: 87
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.3957 dB
# Epoch: 88
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 22.4186 dB
# Epoch: 89
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 22.4487 dB
# Epoch: 90
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.4711 dB
# Epoch: 91
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.5124 dB
# Epoch: 92
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.5371 dB
# Epoch: 93
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.5705 dB
# Epoch: 94
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.5931 dB
# Epoch: 95
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.6089 dB
# Epoch: 96
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 22.6524 dB
# Epoch: 97
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.6776 dB
# Epoch: 98
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.7089 dB
# Epoch: 99
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.7215 dB
# Epoch: 100
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.7573 dB
# Epoch: 101
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.7698 dB
# Epoch: 102
# ===> Train: Avg. Loss: 0.0050
# ===> Test: Avg. PSNR: 22.8022 dB
# Epoch: 103
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.8425 dB
# Epoch: 104
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 22.8689 dB
# Epoch: 105
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.8873 dB
# Epoch: 106
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 22.9205 dB
# Epoch: 107
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.9467 dB
# Epoch: 108
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 22.9580 dB
# Epoch: 109
# ===> Train: Avg. Loss: 0.0049
# ===> Test: Avg. PSNR: 22.9955 dB
# Epoch: 110
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.0191 dB
# Epoch: 111
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 23.0409 dB
# Epoch: 112
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 23.0457 dB
# Epoch: 113
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.0903 dB
# Epoch: 114
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 23.0616 dB
# Epoch: 115
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.1427 dB
# Epoch: 116
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.0994 dB
# Epoch: 117
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.1895 dB
# Epoch: 118
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.1719 dB
# Epoch: 119
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.2276 dB
# Epoch: 120
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.1772 dB
# Epoch: 121
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.2796 dB
# Epoch: 122
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.2800 dB
# Epoch: 123
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.3253 dB
# Epoch: 124
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.3206 dB
# Epoch: 125
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.3674 dB
# Epoch: 126
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.3839 dB
# Epoch: 127
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.3930 dB
# Epoch: 128
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.4298 dB
# Epoch: 129
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.4492 dB
# Epoch: 130
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.4702 dB
# Epoch: 131
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.4701 dB
# Epoch: 132
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.5133 dB
# Epoch: 133
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.5282 dB
# Epoch: 134
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.5416 dB
# Epoch: 135
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.5597 dB
# Epoch: 136
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.5954 dB
# Epoch: 137
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6158 dB
# Epoch: 138
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6335 dB
# Epoch: 139
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6545 dB
# Epoch: 140
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.6630 dB
# Epoch: 141
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.6410 dB
# Epoch: 142
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6813 dB
# Epoch: 143
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.6929 dB
# Epoch: 144
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.6948 dB
# Epoch: 145
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.7507 dB
# Epoch: 146
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.7406 dB
# Epoch: 147
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.8019 dB
# Epoch: 148
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.8133 dB
# Epoch: 149
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.8386 dB
# Epoch: 150
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.8530 dB
# Epoch: 151
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.8545 dB
# Epoch: 152
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.8771 dB
# Epoch: 153
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.9110 dB
# Epoch: 154
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 23.8785 dB
# Epoch: 155
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.9279 dB
# Epoch: 156
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.9567 dB
# Epoch: 157
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.9798 dB
# Epoch: 158
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.9973 dB
# Epoch: 159
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 24.0006 dB
# Epoch: 160
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 24.0018 dB
# Epoch: 161
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 24.0495 dB
# Epoch: 162
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.9336 dB
# Epoch: 163
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 24.0699 dB
# Epoch: 164
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.1098 dB
# Epoch: 165
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 21.3425 dB
# Epoch: 166
# ===> Train: Avg. Loss: 0.0060
# ===> Test: Avg. PSNR: 17.9995 dB
# Epoch: 167
# ===> Train: Avg. Loss: 0.0132
# ===> Test: Avg. PSNR: 19.5071 dB
# Epoch: 168
# ===> Train: Avg. Loss: 0.0089
# ===> Test: Avg. PSNR: 20.7300 dB
# Epoch: 169
# ===> Train: Avg. Loss: 0.0070
# ===> Test: Avg. PSNR: 20.0850 dB
# Epoch: 170
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 20.8565 dB
# Epoch: 171
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 22.5790 dB
# Epoch: 172
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 24.0009 dB
# Epoch: 173
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.6605 dB
# Epoch: 174
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.4989 dB
# Epoch: 175
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.8626 dB
# Epoch: 176
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.0840 dB
# Epoch: 177
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.9691 dB
# Epoch: 178
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 23.8897 dB
# Epoch: 179
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.0329 dB
# Epoch: 180
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.1738 dB
# Epoch: 181
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.1653 dB
# Epoch: 182
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.1868 dB
# Epoch: 183
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 24.2180 dB
# Epoch: 184
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.2374 dB
# Epoch: 185
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.2535 dB
# Epoch: 186
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 24.2686 dB
# Epoch: 187
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.2827 dB
# Epoch: 188
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.2989 dB
# Epoch: 189
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.3087 dB
# Epoch: 190
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.3180 dB
# Epoch: 191
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 24.3312 dB
# Epoch: 192
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.3414 dB
# Epoch: 193
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.3516 dB
# Epoch: 194
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.3842 dB
# Epoch: 195
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.3988 dB
# Epoch: 196
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.4032 dB
# Epoch: 197
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.4090 dB
# Epoch: 198
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.4300 dB
# Epoch: 199
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.4375 dB
# Epoch: 200
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.4515 dB
# Epoch: 201
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.4670 dB
# Epoch: 202
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.4806 dB
# Epoch: 203
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.5012 dB
# Epoch: 204
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.5147 dB
# Epoch: 205
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.5337 dB
# Epoch: 206
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.5461 dB
# Epoch: 207
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.5587 dB
# Epoch: 208
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.5690 dB
# Epoch: 209
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.5854 dB
# Epoch: 210
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.5990 dB
# Epoch: 211
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.6128 dB
# Epoch: 212
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.6251 dB
# Epoch: 213
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.6365 dB
# Epoch: 214
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.6512 dB
# Epoch: 215
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.6649 dB
# Epoch: 216
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.6778 dB
# Epoch: 217
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.6912 dB
# Epoch: 218
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.6977 dB
# Epoch: 219
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.7152 dB
# Epoch: 220
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.7279 dB
# Epoch: 221
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.7419 dB
# Epoch: 222
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.7411 dB
# Epoch: 223
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.7634 dB
# Epoch: 224
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.7551 dB
# Epoch: 225
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.7810 dB
# Epoch: 226
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.8031 dB
# Epoch: 227
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 24.8172 dB
# Epoch: 228
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.8291 dB
# Epoch: 229
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.8405 dB
# Epoch: 230
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.8494 dB
# Epoch: 231
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.8651 dB
# Epoch: 232
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.8728 dB
# Epoch: 233
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.8862 dB
# Epoch: 234
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9004 dB
# Epoch: 235
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.9069 dB
# Epoch: 236
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9234 dB
# Epoch: 237
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.9313 dB
# Epoch: 238
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.9485 dB
# Epoch: 239
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 24.9601 dB
# Epoch: 240
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9658 dB
# Epoch: 241
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9628 dB
# Epoch: 242
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.9888 dB
# Epoch: 243
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.0062 dB
# Epoch: 244
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 25.0157 dB
# Epoch: 245
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.0137 dB
# Epoch: 246
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.0280 dB
# Epoch: 247
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.0508 dB
# Epoch: 248
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.0621 dB
# Epoch: 249
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.0700 dB
# Epoch: 250
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.0841 dB
# Epoch: 251
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.0948 dB
# Epoch: 252
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 25.1031 dB
# Epoch: 253
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.1083 dB
# Epoch: 254
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.1242 dB
# Epoch: 255
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.1121 dB
# Epoch: 256
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 25.1403 dB
# Epoch: 257
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.1571 dB
# Epoch: 258
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.1555 dB
# Epoch: 259
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.1781 dB
# Epoch: 260
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.1868 dB
# Epoch: 261
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.1923 dB
# Epoch: 262
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2080 dB
# Epoch: 263
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 25.2170 dB
# Epoch: 264
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.2292 dB
# Epoch: 265
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2310 dB
# Epoch: 266
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.2467 dB
# Epoch: 267
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.2579 dB
# Epoch: 268
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2629 dB
# Epoch: 269
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2732 dB
# Epoch: 270
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2738 dB
# Epoch: 271
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.2683 dB
# Epoch: 272
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.2926 dB
# Epoch: 273
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.3094 dB
# Epoch: 274
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3184 dB
# Epoch: 275
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3322 dB
# Epoch: 276
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.3282 dB
# Epoch: 277
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.3476 dB
# Epoch: 278
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.3507 dB
# Epoch: 279
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3658 dB
# Epoch: 280
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3635 dB
# Epoch: 281
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3841 dB
# Epoch: 282
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.3883 dB
# Epoch: 283
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 25.3962 dB
# Epoch: 284
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4104 dB
# Epoch: 285
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4149 dB
# Epoch: 286
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4256 dB
# Epoch: 287
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4263 dB
# Epoch: 288
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4428 dB
# Epoch: 289
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.4490 dB
# Epoch: 290
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4595 dB
# Epoch: 291
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.4670 dB
# Epoch: 292
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.4765 dB
# Epoch: 293
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.4792 dB
# Epoch: 294
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4906 dB
# Epoch: 295
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4918 dB
# Epoch: 296
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.4994 dB
# Epoch: 297
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4817 dB
# Epoch: 298
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5123 dB
# Epoch: 299
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5102 dB
# Epoch: 300
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.5335 dB
# Epoch: 301
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5413 dB
# Epoch: 302
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5476 dB
# Epoch: 303
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5642 dB
# Epoch: 304
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.5715 dB
# Epoch: 305
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5796 dB
# Epoch: 306
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5871 dB
# Epoch: 307
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5909 dB
# Epoch: 308
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.5784 dB
# Epoch: 309
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6093 dB
# Epoch: 310
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6115 dB
# Epoch: 311
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6246 dB
# Epoch: 312
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.6303 dB
# Epoch: 313
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6351 dB
# Epoch: 314
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6418 dB
# Epoch: 315
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6526 dB
# Epoch: 316
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6573 dB
# Epoch: 317
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6665 dB
# Epoch: 318
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6775 dB
# Epoch: 319
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6709 dB
# Epoch: 320
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6751 dB
# Epoch: 321
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.6945 dB
# Epoch: 322
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.7036 dB
# Epoch: 323
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7143 dB
# Epoch: 324
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7145 dB
# Epoch: 325
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.7251 dB
# Epoch: 326
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7341 dB
# Epoch: 327
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.7261 dB
# Epoch: 328
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7379 dB
# Epoch: 329
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7551 dB
# Epoch: 330
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7625 dB
# Epoch: 331
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7705 dB
# Epoch: 332
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7715 dB
# Epoch: 333
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7735 dB
# Epoch: 334
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7922 dB
# Epoch: 335
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.7906 dB
# Epoch: 336
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8066 dB
# Epoch: 337
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.8099 dB
# Epoch: 338
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8117 dB
# Epoch: 339
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8204 dB
# Epoch: 340
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.8333 dB
# Epoch: 341
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8296 dB
# Epoch: 342
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.8474 dB
# Epoch: 343
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8450 dB
# Epoch: 344
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.8538 dB
# Epoch: 345
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8691 dB
# Epoch: 346
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 25.8764 dB
# Epoch: 347
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8795 dB
# Epoch: 348
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8820 dB
# Epoch: 349
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8952 dB
# Epoch: 350
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8962 dB
# Epoch: 351
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9075 dB
# Epoch: 352
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9158 dB
# Epoch: 353
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.9125 dB
# Epoch: 354
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.9287 dB
# Epoch: 355
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9341 dB
# Epoch: 356
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9379 dB
# Epoch: 357
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9438 dB
# Epoch: 358
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9539 dB
# Epoch: 359
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.9602 dB
# Epoch: 360
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 25.9669 dB
# Epoch: 361
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9727 dB
# Epoch: 362
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9773 dB
# Epoch: 363
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9843 dB
# Epoch: 364
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9910 dB
# Epoch: 365
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9975 dB
# Epoch: 366
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0035 dB
# Epoch: 367
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0088 dB
# Epoch: 368
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0149 dB
# Epoch: 369
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0209 dB
# Epoch: 370
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0256 dB
# Epoch: 371
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0281 dB
# Epoch: 372
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0307 dB
# Epoch: 373
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0384 dB
# Epoch: 374
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0360 dB
# Epoch: 375
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.0384 dB
# Epoch: 376
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0504 dB
# Epoch: 377
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0584 dB
# Epoch: 378
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0708 dB
# Epoch: 379
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0776 dB
# Epoch: 380
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0811 dB
# Epoch: 381
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0870 dB
# Epoch: 382
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0872 dB
# Epoch: 383
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0962 dB
# Epoch: 384
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1027 dB
# Epoch: 385
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1093 dB
# Epoch: 386
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1131 dB
# Epoch: 387
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1190 dB
# Epoch: 388
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1179 dB
# Epoch: 389
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1132 dB
# Epoch: 390
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1328 dB
# Epoch: 391
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1401 dB
# Epoch: 392
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1442 dB
# Epoch: 393
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1441 dB
# Epoch: 394
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1355 dB
# Epoch: 395
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1565 dB
# Epoch: 396
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1560 dB
# Epoch: 397
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1524 dB
# Epoch: 398
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0674 dB
# Epoch: 399
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1577 dB
# Epoch: 400
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1487 dB
# Epoch: 401
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1800 dB
# Epoch: 402
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1768 dB
# Epoch: 403
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1949 dB
# Epoch: 404
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2012 dB
# Epoch: 405
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1019 dB
# Epoch: 406
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1933 dB
# Epoch: 407
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 26.2066 dB
# Epoch: 408
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1909 dB
# Epoch: 409
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2236 dB
# Epoch: 410
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2300 dB
# Epoch: 411
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9689 dB
# Epoch: 412
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1712 dB
# Epoch: 413
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2372 dB
# Epoch: 414
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2437 dB
# Epoch: 415
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1815 dB
# Epoch: 416
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.7214 dB
# Epoch: 417
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2207 dB
# Epoch: 418
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2662 dB
# Epoch: 419
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1100 dB
# Epoch: 420
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2253 dB
# Epoch: 421
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2776 dB
# Epoch: 422
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2663 dB
# Epoch: 423
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2281 dB
# Epoch: 424
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2914 dB
# Epoch: 425
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2953 dB
# Epoch: 426
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2665 dB
# Epoch: 427
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1955 dB
# Epoch: 428
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2920 dB
# Epoch: 429
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2989 dB
# Epoch: 430
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0403 dB
# Epoch: 431
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.9246 dB
# Epoch: 432
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 25.6313 dB
# Epoch: 433
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 23.7464 dB
# Epoch: 434
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.6377 dB
# Epoch: 435
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 23.7508 dB
# Epoch: 436
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 25.7294 dB
# Epoch: 437
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 17.1474 dB
# Epoch: 438
# ===> Train: Avg. Loss: 0.0203
# ===> Test: Avg. PSNR: 19.3092 dB
# Epoch: 439
# ===> Train: Avg. Loss: 0.0166
# ===> Test: Avg. PSNR: 16.8299 dB
# Epoch: 440
# ===> Train: Avg. Loss: 0.0174
# ===> Test: Avg. PSNR: 14.9444 dB
# Epoch: 441
# ===> Train: Avg. Loss: 0.0164
# ===> Test: Avg. PSNR: 25.1585 dB
# Epoch: 442
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 18.3323 dB
# Epoch: 443
# ===> Train: Avg. Loss: 0.0098
# ===> Test: Avg. PSNR: 23.8065 dB
# Epoch: 444
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 19.9627 dB
# Epoch: 445
# ===> Train: Avg. Loss: 0.0073
# ===> Test: Avg. PSNR: 24.4901 dB
# Epoch: 446
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 22.8095 dB
# Epoch: 447
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 24.4952 dB
# Epoch: 448
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.9060 dB
# Epoch: 449
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.6095 dB
# Epoch: 450
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.7011 dB
# Epoch: 451
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5132 dB
# Epoch: 452
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9486 dB
# Epoch: 453
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8140 dB
# Epoch: 454
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0118 dB
# Epoch: 455
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 25.8907 dB
# Epoch: 456
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0758 dB
# Epoch: 457
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9955 dB
# Epoch: 458
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1336 dB
# Epoch: 459
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0868 dB
# Epoch: 460
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1659 dB
# Epoch: 461
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.1488 dB
# Epoch: 462
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1829 dB
# Epoch: 463
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2096 dB
# Epoch: 464
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.1957 dB
# Epoch: 465
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2344 dB
# Epoch: 466
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2234 dB
# Epoch: 467
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2541 dB
# Epoch: 468
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2575 dB
# Epoch: 469
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2740 dB
# Epoch: 470
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2832 dB
# Epoch: 471
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2906 dB
# Epoch: 472
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3015 dB
# Epoch: 473
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.3086 dB
# Epoch: 474
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3154 dB
# Epoch: 475
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3242 dB
# Epoch: 476
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3307 dB
# Epoch: 477
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3372 dB
# Epoch: 478
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.3434 dB
# Epoch: 479
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3492 dB
# Epoch: 480
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.3547 dB
# Epoch: 481
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3595 dB
# Epoch: 482
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3650 dB
# Epoch: 483
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3697 dB
# Epoch: 484
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3747 dB
# Epoch: 485
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3796 dB
# Epoch: 486
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3839 dB
# Epoch: 487
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3888 dB
# Epoch: 488
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3935 dB
# Epoch: 489
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3975 dB
# Epoch: 490
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.4017 dB
# Epoch: 491
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.4058 dB
# Epoch: 492
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4098 dB
# Epoch: 493
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4137 dB
# Epoch: 494
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4164 dB
# Epoch: 495
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4212 dB
# Epoch: 496
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4249 dB
# Epoch: 497
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4289 dB
# Epoch: 498
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4325 dB
# Epoch: 499
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4357 dB
# Epoch: 500
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4393 dB
# Checkpoint saved to model_extendNet_epoch_500.pth

# %% [markdown]
# # References:
#
# PyTorch Examples: https://github.com/pytorch/examples/
#
# Plotting: https://www.pluralsight.com/guides/data-visualization-deep-learning-model-using-matplotlib
#
# Real-Time Single Image and Video Super-Resolution Using an Efficient Sub-Pixel Convolutional Neural Network: https://arxiv.org/pdf/1609.05158.pdf
