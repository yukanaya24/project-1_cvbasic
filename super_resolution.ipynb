# %% [markdown]
# <a href="https://colab.research.google.com/github/yukanaya24/project-1_cvbasic/blob/main/super_resolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # On how to train and test a deep neural network for the super-resolution task.
# > Prepared by Man M. Ho

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/共有/cvbasic_project"
# Out:
# /content/drive/MyDrive/共有/cvbasic_project

# %% [markdown]
# # Import Libraries

# %%
# For Path Processing
from os.path import exists, join, basename
from os import makedirs, remove, getcwd, listdir

# To download and extract datasets
from six.moves import urllib
import tarfile

# For Datasets and Transformation
from PIL import Image
import torch.utils.data as data
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, CenterCrop, ToTensor, Resize

# For Network Architecture
import torch
import torch.nn as nn
import torch.nn.init as init

# PyTorch Optimizer
import torch.optim as optim

# Others
import numpy as np
from math import log10
import matplotlib.pyplot as plt # For plotting

# %% [markdown]
# # Data Preparation and Dataset
#
# Here is the Python code for downloading and extracting the dataset.

# %%
def download_bsds300(dest: str = "dataset") -> None:
    current_dir: str = getcwd()
    output_image_dir: str = join(current_dir, dest, "BSDS300/images")

    if not exists(output_image_dir):
        makedirs(dest)
        url: str = "http://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300-images.tgz"
        print("Downloading Dataset at ", url)

        data: urllib.request.addinfourl = urllib.request.urlopen(url)

        file_path: str = join(dest, basename(url))
        with open(file_path, 'wb') as f:
            f.write(data.read())

        print("Extracting Data")
        with tarfile.open(file_path) as tar:
            for item in tar:
                tar.extract(item, dest)

        remove(file_path)
    print('Done! Extracted Dataset is saved at : ' + join(output_image_dir))

# %%
download_bsds300()
# Out:
# Done! Extracted Dataset is saved at : /content/drive/MyDrive/共有/cvbasic_project/dataset/BSDS300/images

# %% [markdown]
# Now we have downloaded the dataset, let's prepare for the dataloader!

# %%
# Check whether your file ends with the exts ".png", ".jpg", and ".jpeg".
def is_image_file(filename: str) -> bool:
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg"])


# Load image using PIL.Image and convert RGB to YCbCr,
# where: Y is luma/gray component, Cb and CR are chroma/color components.
# In this work, we only up-sample the Y.
def load_img(filepath: str) -> Image.Image:
    img: Image.Image = Image.open(filepath).convert('YCbCr')
    y, _, _ = img.split()   # Y, Cb, Crに分割しYチャネルのみを返す
    return y


class DatasetFromFolder(data.Dataset):
    def __init__(self, image_dir: str, input_transform: Optional[Compose] = None, target_transform: Optional[Compose] = None) -> None:
        super(DatasetFromFolder, self).__init__()
        self.image_filenames: list[str] = [join(image_dir, x) for x in listdir(image_dir) if is_image_file(x)]

        self.input_transform = input_transform
        self.target_transform = target_transform


    def __getitem__(self, index: int) -> tuple[torch.Tensor, torch.Tensor]:
        # Load Images
        input: Image.Image = load_img(self.image_filenames[index])
        target: Image.Image = input.copy()

        # Input is resize 1/scale as described in the function input_transform
        if self.input_transform:
            input = self.input_transform(input)
        # Target is the original image
        if self.target_transform:
            target = self.target_transform(target)

        return input, target


    def __len__(self) -> int:
        return len(self.image_filenames)


# result the suitable crop_size for upscale_factor
def calculate_valid_crop_size(crop_size: int, upscale_factor: int) -> int:
    return crop_size - (crop_size % upscale_factor)


def input_transform(crop_size: int, upscale_factor: int) -> Compose:
    return Compose([
        CenterCrop(crop_size),
        Resize(crop_size // upscale_factor),
        ToTensor(),
    ])


def target_transform(crop_size: int) -> Compose:
    return Compose([
        CenterCrop(crop_size),
        ToTensor(),
    ])


# This result Pytorch Dataset for training
def get_training_set(root_dir: str, upscale_factor: int) -> DatasetFromFolder:
    train_dir: str = join(root_dir, "train")
    crop_size: int = calculate_valid_crop_size(256, upscale_factor)

    return DatasetFromFolder(train_dir,
                             input_transform=input_transform(crop_size, upscale_factor),
                             target_transform=target_transform(crop_size))

# This result Pytorch Dataset for testing
def get_test_set(root_dir, upscale_factor):
    test_dir = join(root_dir, "test")
    crop_size = calculate_valid_crop_size(256, upscale_factor)

    return DatasetFromFolder(test_dir,
                             input_transform=input_transform(crop_size, upscale_factor),
                             target_transform=target_transform(crop_size))

# %% [markdown]
# # Network Architecture
# ![Screenshot_308.png](data:image/png;base64,...)

# %% [markdown]
# Regarding the network architecture, we utilize Efficient Sub-Pixel Convolutional Neural Network (ESPCN, https://arxiv.org/pdf/1609.05158.pdf
# ) with N convolutional layers (they set N=4 in the code), the feature size in the inference order are as:
#
# ---
# Input Y: H x W x 1
#
# ---
# Conv1 x ReLU:
#
# H x W x 1 --> H x W x 64
#
# ---
# Conv2 x ReLU:
#
# H x W x 64 --> H x W x 64
#
# ---
# Conv3 x ReLU:
#
# H x W x 64 --> H x W x 32
#
# ---
# Conv4:
#
# H x W x 32 --> H x W x (upscale_factor ** 2)
#
# ---
# Pixel_Shuffle:
#
# H x W x (upscale_factor ** 2) --> H' x W' x 1
#
# where:
#
# H' = H * upscale_factor
#
# W' = W * upscale_factor
#
# Pixel shuffle technique converts a feature map of H x W x (upscale_factor**2) to the high-resolution output image H' x W' x 1
#
# ---
# A code for the network is as:

# %%
class Net(nn.Module):
    def __init__(self, upscale_factor: int) -> None:
        super(Net, self).__init__()

        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
        self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
        self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
        self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
        self.pixel_shuffle = nn.PixelShuffle(upscale_factor)

        self._initialize_weights()

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.relu(self.conv3(x))
        x = self.pixel_shuffle(self.conv4(x))
        return x

    def _initialize_weights(self) -> None:
        init.orthogonal_(self.conv1.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv2.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv3.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv4.weight)

# %% [markdown]
# # Train Models

# %% [markdown]
# ## Set hyperparameters

# %%
args = {}
# here is where BSD300 dataset is saved
args['root_dir'] = './dataset/BSDS300/images'
# super resolution upscale factor
args['upscale_factor'] = 2
# training batch size
args['batchSize'] = 64
# testing batch size
args['testBatchSize'] = 10
# number of epochs to train for
args['nEpochs'] = 50
# Learning Rate
args['lr'] = 0.01
# number of threads for data loader to use
args['threads'] = 4
# random seed to use
args['seed'] = 42

# %% [markdown]
# ## This keeps your random function consistent for every run so that you can reproduce your results.

# %%
torch.manual_seed(args['seed'])

# %% [markdown]
# ## Declare training and test dataloader

# %%
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)

# %% [markdown]
# ## Declare model and criteria

# %%
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()

# %% [markdown]
# ## Declare optimizer
#
# Adam: https://arxiv.org/abs/1412.6980

# %%
optimizer = optim.Adam(model.parameters(), lr=args['lr'])

# %% [markdown]
# ## Training function

# %%
def train(epoch) -> float:
    print('Epoch: {}'.format(epoch))
    epoch_loss = 0
    for iteration, batch in enumerate(training_data_loader, 1):
        input, target = batch[0].cuda(), batch[1].cuda()

        optimizer.zero_grad()
        loss = training_loss_fn(model(input), target)
        epoch_loss += loss.item()
        loss.backward()
        optimizer.step()

        # print("===> Epoch[{}]({}/{}): Loss: {:.4f}".format(epoch, iteration, len(training_data_loader), loss.item()))

    print("===> Train: Avg. Loss: {:.4f}".format(epoch_loss / len(training_data_loader)))
    return epoch_loss / len(training_data_loader)

# %% [markdown]
# ## Test function

# %%
def test() -> tuple[float, float]:
    avg_psnr = 0
    with torch.no_grad():
        for batch in testing_data_loader:
            input, target = batch[0].cuda(), batch[1].cuda()

            prediction = model(input)
            mse = mse_fn(prediction, target)
            psnr = 10 * log10(1 / mse.item())
            avg_psnr += psnr
    print("===> Test: Avg. PSNR: {:.4f} dB".format(avg_psnr / len(testing_data_loader)))
    return avg_psnr / len(testing_data_loader)

# %% [markdown]
# ## Save checkpoint

# %%
def save_checkpoint(epoch, model_name='model'):
    model_out_path = model_name + "_epoch_{}.pth".format(epoch)
    torch.save(model, model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))

# %% [markdown]
# ## Train models

# %% [markdown]
# We are using BSDS300 dataset, MSE for the loss function, and a network architecture with 4 convolutional layers.

# %%
base_train_errors = []
base_test_psnrs = []
for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    base_train_errors.append(train_error)
    base_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_base')

# Plotting errors
## Note for plot function, Args from left to right:
### range,
### list of values,
### color such as 'g' -> green, 'b' --> blue, 'r' --> red
#### See more colors here https://matplotlib.org/stable/gallery/color/named_colors.html
### label
plt.figure()
plt.plot(range(1, args['nEpochs'] + 1), base_train_errors, 'g', label='Base Model')
# plt.plot(range(1, args['nEpochs'] + 1), bsds500_train_errors, 'b', label='BSDS500 Model') # You can add another model like this
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.legend()
plt.show()

plt.figure()
plt.plot(range(1, args['nEpochs'] + 1), base_test_psnrs, 'g', label='Base Model')
# plt.plot(range(1, args['nEpochs'] + 1), bsds500_test_psnrs, 'b', label='Base Model')# You can add another model like this
plt.title('Val PSNR')
plt.xlabel('Epoch')
plt.ylabel('PSNR')
plt.legend()
plt.show()
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 3.3200
# ===> Test: Avg. PSNR: 6.0919 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.1957
# ===> Test: Avg. PSNR: 10.3417 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.0640
# ===> Test: Avg. PSNR: 13.1905 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.0338
# ===> Test: Avg. PSNR: 13.2375 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0405
# ===> Test: Avg. PSNR: 15.8666 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0266
# ===> Test: Avg. PSNR: 15.1404 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0225
# ===> Test: Avg. PSNR: 16.0681 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0219
# ===> Test: Avg. PSNR: 17.2861 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0184
# ===> Test: Avg. PSNR: 17.4022 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0170
# ===> Test: Avg. PSNR: 17.8122 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0153
# ===> Test: Avg. PSNR: 18.2011 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0140
# ===> Test: Avg. PSNR: 18.6446 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0129
# ===> Test: Avg. PSNR: 18.8822 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0123
# ===> Test: Avg. PSNR: 18.9770 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0116
# ===> Test: Avg. PSNR: 19.1303 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0114
# ===> Test: Avg. PSNR: 19.2130 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0111
# ===> Test: Avg. PSNR: 19.2979 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0113
# ===> Test: Avg. PSNR: 19.3446 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0107
# ===> Test: Avg. PSNR: 19.4023 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0108
# ===> Test: Avg. PSNR: 19.4488 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0109
# ===> Test: Avg. PSNR: 19.4981 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0109
# ===> Test: Avg. PSNR: 19.5406 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.5967 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0102
# ===> Test: Avg. PSNR: 19.6478 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0102
# ===> Test: Avg. PSNR: 19.7059 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0100
# ===> Test: Avg. PSNR: 19.7775 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0096
# ===> Test: Avg. PSNR: 19.8824 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 20.0663 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0091
# ===> Test: Avg. PSNR: 20.3250 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0090
# ===> Test: Avg. PSNR: 20.4859 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0096
# ===> Test: Avg. PSNR: 18.1155 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0129
# ===> Test: Avg. PSNR: 18.0069 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0119
# ===> Test: Avg. PSNR: 18.9553 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0103
# ===> Test: Avg. PSNR: 19.5266 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0106
# ===> Test: Avg. PSNR: 19.9527 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 20.2303 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0098
# ===> Test: Avg. PSNR: 20.4598 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.7749 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0081
# ===> Test: Avg. PSNR: 20.9429 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0074
# ===> Test: Avg. PSNR: 20.9549 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 21.0059 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 21.1396 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0072
# ===> Test: Avg. PSNR: 21.1392 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0074
# ===> Test: Avg. PSNR: 21.2330 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 21.3108 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0068
# ===> Test: Avg. PSNR: 21.3447 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0068
# ===> Test: Avg. PSNR: 21.3826 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0067
# ===> Test: Avg. PSNR: 21.4238 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.4652 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.5015 dB
# Checkpoint saved to model_base_epoch_50.pth

# %% [markdown]
# # Tasks
# Task 1. 学習済みモデルを用いて、1枚の画像に対するテスト結果を確認する（20点）
#
# Task 2. 損失関数に関するアブレーションスタディを実施する。各損失関数を用いた際のモデル性能（PSNR）を比較する。（30点）
#
# Task 3. ネットワーク構造やハイパーパラメータなどを調整し、性能（PSNR）の向上を図る（50点）
#
# 上記に示したトレーニング損失や検証時のPSNRのプロット方法を参考にしてください。

# %% [markdown]
# ##Task 1. Test the trained model on your own images
#
# The run function is as:

# %%
def run_model(input_image, output_filename, model_path):
  img = Image.open(input_image).convert('YCbCr')
  y, cb, cr = img.split()

  model = torch.load(model_path, weights_only=False)
  img_to_tensor = ToTensor()
  input = img_to_tensor(y).view(1, -1, y.size[1], y.size[0])

  model = model.cuda()
  input = input.cuda()

  out = model(input)
  out = out.cpu()
  out_img_y = out[0].detach().numpy()
  out_img_y *= 255.0
  out_img_y = out_img_y.clip(0, 255)
  out_img_y = Image.fromarray(np.uint8(out_img_y[0]), mode='L')

  out_img_cb = cb.resize(out_img_y.size, Image.BICUBIC)
  out_img_cr = cr.resize(out_img_y.size, Image.BICUBIC)
  out_img = Image.merge('YCbCr', [out_img_y, out_img_cb, out_img_cr]).convert('RGB')

  out_img.save(output_filename)
  print('Output image saved to ', output_filename)
  return img.convert('RGB'), out_img

# %%
# An example
input_image = "./dataset/BSDS300/images/test/101085.jpg"
output_filename = "101085_x2.jpg"

model_path = "model_base_epoch_50.pth"
img, out_img = run_model(input_image, output_filename, model_path)
# Out:
# Output image saved to  101085_x2.jpg

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=321x481>

# %%
out_img
# Out:
# <PIL.Image.Image image mode=RGB size=642x962>

# %% [markdown]
# ##Task 2. Conduct an ablation study on loss function.
#
# MSE（Mean Square Error：平均二乗誤差）以外にも、画像生成に用いられる損失関数は多数存在します。以下はその一部です：
#
# L1: https://pytorch.org/docs/stable/generated/torch.nn.L1Loss.html#torch.nn.L1Loss
#
# L1 Smooth: https://pytorch.org/docs/stable/generated/torch.nn.SmoothL1Loss.html#torch.nn.SmoothL1Loss
#
# Huber Loss: https://pytorch.org/docs/stable/generated/torch.nn.HuberLoss.html#torch.nn.HuberLoss
#
# MS-SSIM: https://github.com/jorge-pessoa/pytorch-msssim
#
# LPIPS: https://github.com/richzhang/PerceptualSimilarity
#
# MSE以外の損失関数に変更し、結果を分析してください。
# 以下はL1損失関数に変更する例です。

# %%
# Baseline, training_loss_fn is commented for changing
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
# training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)

# Change the Training Loss Function
training_loss_fn = nn.L1Loss()

l1loss_train_errors = []
l1loss_test_psnrs = []

for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    l1loss_train_errors.append(train_error)
    l1loss_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_l1loss')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 1.6015
# ===> Test: Avg. PSNR: 7.0074 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.3006
# ===> Test: Avg. PSNR: 12.8241 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.1551
# ===> Test: Avg. PSNR: 14.2359 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.1276
# ===> Test: Avg. PSNR: 16.4913 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0936
# ===> Test: Avg. PSNR: 18.7416 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0812
# ===> Test: Avg. PSNR: 18.0324 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0818
# ===> Test: Avg. PSNR: 18.4880 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0717
# ===> Test: Avg. PSNR: 19.0225 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0686
# ===> Test: Avg. PSNR: 20.0843 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0645
# ===> Test: Avg. PSNR: 17.5860 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0740
# ===> Test: Avg. PSNR: 20.2568 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0595
# ===> Test: Avg. PSNR: 20.4275 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0621
# ===> Test: Avg. PSNR: 20.5535 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0602
# ===> Test: Avg. PSNR: 20.8006 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0610
# ===> Test: Avg. PSNR: 20.3346 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0589
# ===> Test: Avg. PSNR: 21.1010 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0526
# ===> Test: Avg. PSNR: 21.3682 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0537
# ===> Test: Avg. PSNR: 21.4487 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0502
# ===> Test: Avg. PSNR: 21.0592 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0543
# ===> Test: Avg. PSNR: 21.5197 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0538
# ===> Test: Avg. PSNR: 21.7178 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0523
# ===> Test: Avg. PSNR: 20.2433 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0617
# ===> Test: Avg. PSNR: 20.0703 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0674
# ===> Test: Avg. PSNR: 21.2585 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0633
# ===> Test: Avg. PSNR: 20.9305 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0615
# ===> Test: Avg. PSNR: 21.4978 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0548
# ===> Test: Avg. PSNR: 21.6897 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0503
# ===> Test: Avg. PSNR: 21.9012 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0493
# ===> Test: Avg. PSNR: 21.5329 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0535
# ===> Test: Avg. PSNR: 21.4484 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0536
# ===> Test: Avg. PSNR: 20.1366 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0703
# ===> Test: Avg. PSNR: 20.1115 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0684
# ===> Test: Avg. PSNR: 22.0179 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0577
# ===> Test: Avg. PSNR: 20.7811 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0583
# ===> Test: Avg. PSNR: 21.6481 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0546
# ===> Test: Avg. PSNR: 22.1881 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0544
# ===> Test: Avg. PSNR: 21.7674 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0476
# ===> Test: Avg. PSNR: 22.5028 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0448
# ===> Test: Avg. PSNR: 22.5955 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0439
# ===> Test: Avg. PSNR: 22.7104 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0440
# ===> Test: Avg. PSNR: 22.7941 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0409
# ===> Test: Avg. PSNR: 22.6789 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0443
# ===> Test: Avg. PSNR: 23.0168 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0445
# ===> Test: Avg. PSNR: 22.9457 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0441
# ===> Test: Avg. PSNR: 23.2405 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0412
# ===> Test: Avg. PSNR: 23.3122 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0403
# ===> Test: Avg. PSNR: 23.1830 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0398
# ===> Test: Avg. PSNR: 23.3072 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0424
# ===> Test: Avg. PSNR: 22.8168 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0457
# ===> Test: Avg. PSNR: 21.3584 dB
# Checkpoint saved to model_l1loss_epoch_50.pth

# %% [markdown]
# ##Task 3 Optimization

# %% [markdown]
# ###3.1 Modify hyper parameters

# %%
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)



args['nEpochs'] = 500

epoch500extend_train_errors = []
epoch500extend_test_psnrs = []

for epoch in range(1, args['nEpochs']  + 1):
    train_error = train(epoch)
    test_psnr = test()
    epoch500extend_train_errors.append(train_error)
    epoch500extend_test_psnrs.append(test_psnr)

save_checkpoint(args['nEpochs'], model_name='model_epoch500extend')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# Epoch: 1
# ===> Train: Avg. Loss: 3.3200
# ===> Test: Avg. PSNR: 6.0919 dB
# Epoch: 2
# ===> Train: Avg. Loss: 0.1957
# ===> Test: Avg. PSNR: 10.3417 dB
# Epoch: 3
# ===> Train: Avg. Loss: 0.0640
# ===> Test: Avg. PSNR: 13.1905 dB
# Epoch: 4
# ===> Train: Avg. Loss: 0.0338
# ===> Test: Avg. PSNR: 13.2375 dB
# Epoch: 5
# ===> Train: Avg. Loss: 0.0405
# ===> Test: Avg. PSNR: 15.8666 dB
# Epoch: 6
# ===> Train: Avg. Loss: 0.0266
# ===> Test: Avg. PSNR: 15.1404 dB
# Epoch: 7
# ===> Train: Avg. Loss: 0.0225
# ===> Test: Avg. PSNR: 16.0681 dB
# Epoch: 8
# ===> Train: Avg. Loss: 0.0219
# ===> Test: Avg. PSNR: 17.2861 dB
# Epoch: 9
# ===> Train: Avg. Loss: 0.0184
# ===> Test: Avg. PSNR: 17.4022 dB
# Epoch: 10
# ===> Train: Avg. Loss: 0.0170
# ===> Test: Avg. PSNR: 17.8122 dB
# Epoch: 11
# ===> Train: Avg. Loss: 0.0153
# ===> Test: Avg. PSNR: 18.2011 dB
# Epoch: 12
# ===> Train: Avg. Loss: 0.0140
# ===> Test: Avg. PSNR: 18.6446 dB
# Epoch: 13
# ===> Train: Avg. Loss: 0.0129
# ===> Test: Avg. PSNR: 18.8822 dB
# Epoch: 14
# ===> Train: Avg. Loss: 0.0123
# ===> Test: Avg. PSNR: 18.9770 dB
# Epoch: 15
# ===> Train: Avg. Loss: 0.0116
# ===> Test: Avg. PSNR: 19.1303 dB
# Epoch: 16
# ===> Train: Avg. Loss: 0.0114
# ===> Test: Avg. PSNR: 19.2130 dB
# Epoch: 17
# ===> Train: Avg. Loss: 0.0111
# ===> Test: Avg. PSNR: 19.2979 dB
# Epoch: 18
# ===> Train: Avg. Loss: 0.0113
# ===> Test: Avg. PSNR: 19.3446 dB
# Epoch: 19
# ===> Train: Avg. Loss: 0.0107
# ===> Test: Avg. PSNR: 19.4023 dB
# Epoch: 20
# ===> Train: Avg. Loss: 0.0108
# ===> Test: Avg. PSNR: 19.4488 dB
# Epoch: 21
# ===> Train: Avg. Loss: 0.0109
# ===> Test: Avg. PSNR: 19.4981 dB
# Epoch: 22
# ===> Train: Avg. Loss: 0.0109
# ===> Test: Avg. PSNR: 19.5406 dB
# Epoch: 23
# ===> Train: Avg. Loss: 0.0104
# ===> Test: Avg. PSNR: 19.5967 dB
# Epoch: 24
# ===> Train: Avg. Loss: 0.0102
# ===> Test: Avg. PSNR: 19.6478 dB
# Epoch: 25
# ===> Train: Avg. Loss: 0.0102
# ===> Test: Avg. PSNR: 19.7059 dB
# Epoch: 26
# ===> Train: Avg. Loss: 0.0100
# ===> Test: Avg. PSNR: 19.7775 dB
# Epoch: 27
# ===> Train: Avg. Loss: 0.0096
# ===> Test: Avg. PSNR: 19.8824 dB
# Epoch: 28
# ===> Train: Avg. Loss: 0.0097
# ===> Test: Avg. PSNR: 20.0663 dB
# Epoch: 29
# ===> Train: Avg. Loss: 0.0091
# ===> Test: Avg. PSNR: 20.3250 dB
# Epoch: 30
# ===> Train: Avg. Loss: 0.0090
# ===> Test: Avg. PSNR: 20.4859 dB
# Epoch: 31
# ===> Train: Avg. Loss: 0.0096
# ===> Test: Avg. PSNR: 18.1155 dB
# Epoch: 32
# ===> Train: Avg. Loss: 0.0129
# ===> Test: Avg. PSNR: 18.0069 dB
# Epoch: 33
# ===> Train: Avg. Loss: 0.0119
# ===> Test: Avg. PSNR: 18.9553 dB
# Epoch: 34
# ===> Train: Avg. Loss: 0.0103
# ===> Test: Avg. PSNR: 19.5266 dB
# Epoch: 35
# ===> Train: Avg. Loss: 0.0106
# ===> Test: Avg. PSNR: 19.9527 dB
# Epoch: 36
# ===> Train: Avg. Loss: 0.0095
# ===> Test: Avg. PSNR: 20.2303 dB
# Epoch: 37
# ===> Train: Avg. Loss: 0.0098
# ===> Test: Avg. PSNR: 20.4598 dB
# Epoch: 38
# ===> Train: Avg. Loss: 0.0082
# ===> Test: Avg. PSNR: 20.7749 dB
# Epoch: 39
# ===> Train: Avg. Loss: 0.0081
# ===> Test: Avg. PSNR: 20.9429 dB
# Epoch: 40
# ===> Train: Avg. Loss: 0.0074
# ===> Test: Avg. PSNR: 20.9549 dB
# Epoch: 41
# ===> Train: Avg. Loss: 0.0076
# ===> Test: Avg. PSNR: 21.0059 dB
# Epoch: 42
# ===> Train: Avg. Loss: 0.0069
# ===> Test: Avg. PSNR: 21.1396 dB
# Epoch: 43
# ===> Train: Avg. Loss: 0.0072
# ===> Test: Avg. PSNR: 21.1392 dB
# Epoch: 44
# ===> Train: Avg. Loss: 0.0074
# ===> Test: Avg. PSNR: 21.2330 dB
# Epoch: 45
# ===> Train: Avg. Loss: 0.0075
# ===> Test: Avg. PSNR: 21.3108 dB
# Epoch: 46
# ===> Train: Avg. Loss: 0.0068
# ===> Test: Avg. PSNR: 21.3447 dB
# Epoch: 47
# ===> Train: Avg. Loss: 0.0068
# ===> Test: Avg. PSNR: 21.3826 dB
# Epoch: 48
# ===> Train: Avg. Loss: 0.0067
# ===> Test: Avg. PSNR: 21.4238 dB
# Epoch: 49
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.4652 dB
# Epoch: 50
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.5015 dB
# Epoch: 51
# ===> Train: Avg. Loss: 0.0070
# ===> Test: Avg. PSNR: 21.5343 dB
# Epoch: 52
# ===> Train: Avg. Loss: 0.0061
# ===> Test: Avg. PSNR: 21.5529 dB
# Epoch: 53
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.5963 dB
# Epoch: 54
# ===> Train: Avg. Loss: 0.0066
# ===> Test: Avg. PSNR: 21.6221 dB
# Epoch: 55
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.6546 dB
# Epoch: 56
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.6753 dB
# Epoch: 57
# ===> Train: Avg. Loss: 0.0061
# ===> Test: Avg. PSNR: 21.7160 dB
# Epoch: 58
# ===> Train: Avg. Loss: 0.0059
# ===> Test: Avg. PSNR: 21.7423 dB
# Epoch: 59
# ===> Train: Avg. Loss: 0.0065
# ===> Test: Avg. PSNR: 21.7483 dB
# Epoch: 60
# ===> Train: Avg. Loss: 0.0064
# ===> Test: Avg. PSNR: 21.8088 dB
# Epoch: 61
# ===> Train: Avg. Loss: 0.0062
# ===> Test: Avg. PSNR: 21.8070 dB
# Epoch: 62
# ===> Train: Avg. Loss: 0.0063
# ===> Test: Avg. PSNR: 21.8668 dB
# Epoch: 63
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 21.8869 dB
# Epoch: 64
# ===> Train: Avg. Loss: 0.0060
# ===> Test: Avg. PSNR: 21.9326 dB
# Epoch: 65
# ===> Train: Avg. Loss: 0.0060
# ===> Test: Avg. PSNR: 21.9572 dB
# Epoch: 66
# ===> Train: Avg. Loss: 0.0059
# ===> Test: Avg. PSNR: 21.9951 dB
# Epoch: 67
# ===> Train: Avg. Loss: 0.0057
# ===> Test: Avg. PSNR: 22.0267 dB
# Epoch: 68
# ===> Train: Avg. Loss: 0.0054
# ===> Test: Avg. PSNR: 22.0520 dB
# Epoch: 69
# ===> Train: Avg. Loss: 0.0060
# ===> Test: Avg. PSNR: 22.0904 dB
# Epoch: 70
# ===> Train: Avg. Loss: 0.0060
# ===> Test: Avg. PSNR: 22.1223 dB
# Epoch: 71
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 22.1541 dB
# Epoch: 72
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 22.1800 dB
# Epoch: 73
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 22.1706 dB
# Epoch: 74
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.2372 dB
# Epoch: 75
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.2080 dB
# Epoch: 76
# ===> Train: Avg. Loss: 0.0056
# ===> Test: Avg. PSNR: 22.3025 dB
# Epoch: 77
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.3396 dB
# Epoch: 78
# ===> Train: Avg. Loss: 0.0055
# ===> Test: Avg. PSNR: 22.3701 dB
# Epoch: 79
# ===> Train: Avg. Loss: 0.0058
# ===> Test: Avg. PSNR: 22.3972 dB
# Epoch: 80
# ===> Train: Avg. Loss: 0.0056
# ===> Test: Avg. PSNR: 22.4215 dB
# Epoch: 81
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.4492 dB
# Epoch: 82
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.4841 dB
# Epoch: 83
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 22.5181 dB
# Epoch: 84
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.5344 dB
# Epoch: 85
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.5729 dB
# Epoch: 86
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.5584 dB
# Epoch: 87
# ===> Train: Avg. Loss: 0.0052
# ===> Test: Avg. PSNR: 22.5813 dB
# Epoch: 88
# ===> Train: Avg. Loss: 0.0054
# ===> Test: Avg. PSNR: 22.6576 dB
# Epoch: 89
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 22.6602 dB
# Epoch: 90
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 22.6930 dB
# Epoch: 91
# ===> Train: Avg. Loss: 0.0053
# ===> Test: Avg. PSNR: 22.7251 dB
# Epoch: 92
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.7598 dB
# Epoch: 93
# ===> Train: Avg. Loss: 0.0051
# ===> Test: Avg. PSNR: 22.7822 dB
# Epoch: 94
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.8107 dB
# Epoch: 95
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 22.8126 dB
# Epoch: 96
# ===> Train: Avg. Loss: 0.0049
# ===> Test: Avg. PSNR: 22.8781 dB
# Epoch: 97
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.9054 dB
# Epoch: 98
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 22.9417 dB
# Epoch: 99
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 22.9698 dB
# Epoch: 100
# ===> Train: Avg. Loss: 0.0048
# ===> Test: Avg. PSNR: 22.9937 dB
# Epoch: 101
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 23.0190 dB
# Epoch: 102
# ===> Train: Avg. Loss: 0.0046
# ===> Test: Avg. PSNR: 23.0333 dB
# Epoch: 103
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.0674 dB
# Epoch: 104
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.0857 dB
# Epoch: 105
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.1023 dB
# Epoch: 106
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.2071 dB
# Epoch: 107
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.2753 dB
# Epoch: 108
# ===> Train: Avg. Loss: 0.0047
# ===> Test: Avg. PSNR: 23.3163 dB
# Epoch: 109
# ===> Train: Avg. Loss: 0.0045
# ===> Test: Avg. PSNR: 23.3393 dB
# Epoch: 110
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.3840 dB
# Epoch: 111
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.4387 dB
# Epoch: 112
# ===> Train: Avg. Loss: 0.0043
# ===> Test: Avg. PSNR: 23.4587 dB
# Epoch: 113
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.4810 dB
# Epoch: 114
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.5134 dB
# Epoch: 115
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.5429 dB
# Epoch: 116
# ===> Train: Avg. Loss: 0.0042
# ===> Test: Avg. PSNR: 23.5692 dB
# Epoch: 117
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6010 dB
# Epoch: 118
# ===> Train: Avg. Loss: 0.0044
# ===> Test: Avg. PSNR: 23.5895 dB
# Epoch: 119
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.6586 dB
# Epoch: 120
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.6892 dB
# Epoch: 121
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 23.7509 dB
# Epoch: 122
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.7580 dB
# Epoch: 123
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.8063 dB
# Epoch: 124
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 23.8796 dB
# Epoch: 125
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.4615 dB
# Epoch: 126
# ===> Train: Avg. Loss: 0.0040
# ===> Test: Avg. PSNR: 23.7129 dB
# Epoch: 127
# ===> Train: Avg. Loss: 0.0041
# ===> Test: Avg. PSNR: 23.8625 dB
# Epoch: 128
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.0188 dB
# Epoch: 129
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.2460 dB
# Epoch: 130
# ===> Train: Avg. Loss: 0.0038
# ===> Test: Avg. PSNR: 23.4333 dB
# Epoch: 131
# ===> Train: Avg. Loss: 0.0039
# ===> Test: Avg. PSNR: 23.7473 dB
# Epoch: 132
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.0028 dB
# Epoch: 133
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 23.9513 dB
# Epoch: 134
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.1589 dB
# Epoch: 135
# ===> Train: Avg. Loss: 0.0036
# ===> Test: Avg. PSNR: 24.2927 dB
# Epoch: 136
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.3139 dB
# Epoch: 137
# ===> Train: Avg. Loss: 0.0035
# ===> Test: Avg. PSNR: 24.3735 dB
# Epoch: 138
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.4060 dB
# Epoch: 139
# ===> Train: Avg. Loss: 0.0037
# ===> Test: Avg. PSNR: 24.4838 dB
# Epoch: 140
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.4884 dB
# Epoch: 141
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.5143 dB
# Epoch: 142
# ===> Train: Avg. Loss: 0.0034
# ===> Test: Avg. PSNR: 24.5813 dB
# Epoch: 143
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.6401 dB
# Epoch: 144
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.6087 dB
# Epoch: 145
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.4861 dB
# Epoch: 146
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.7113 dB
# Epoch: 147
# ===> Train: Avg. Loss: 0.0032
# ===> Test: Avg. PSNR: 24.6878 dB
# Epoch: 148
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.7475 dB
# Epoch: 149
# ===> Train: Avg. Loss: 0.0031
# ===> Test: Avg. PSNR: 24.8284 dB
# Epoch: 150
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.8593 dB
# Epoch: 151
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 24.8781 dB
# Epoch: 152
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.9201 dB
# Epoch: 153
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 24.9516 dB
# Epoch: 154
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 24.9295 dB
# Epoch: 155
# ===> Train: Avg. Loss: 0.0033
# ===> Test: Avg. PSNR: 25.0090 dB
# Epoch: 156
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 24.9610 dB
# Epoch: 157
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.7373 dB
# Epoch: 158
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.0615 dB
# Epoch: 159
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 24.9696 dB
# Epoch: 160
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.0618 dB
# Epoch: 161
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.1424 dB
# Epoch: 162
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.1872 dB
# Epoch: 163
# ===> Train: Avg. Loss: 0.0030
# ===> Test: Avg. PSNR: 25.1850 dB
# Epoch: 164
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.2099 dB
# Epoch: 165
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.1846 dB
# Epoch: 166
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.2188 dB
# Epoch: 167
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.1864 dB
# Epoch: 168
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 25.0925 dB
# Epoch: 169
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.3595 dB
# Epoch: 170
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.3325 dB
# Epoch: 171
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.3046 dB
# Epoch: 172
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.3692 dB
# Epoch: 173
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4015 dB
# Epoch: 174
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.4545 dB
# Epoch: 175
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.4302 dB
# Epoch: 176
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5035 dB
# Epoch: 177
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5693 dB
# Epoch: 178
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.5914 dB
# Epoch: 179
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.5964 dB
# Epoch: 180
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.5857 dB
# Epoch: 181
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.6398 dB
# Epoch: 182
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.6569 dB
# Epoch: 183
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.4768 dB
# Epoch: 184
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.6709 dB
# Epoch: 185
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.7163 dB
# Epoch: 186
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 25.7419 dB
# Epoch: 187
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7536 dB
# Epoch: 188
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.7907 dB
# Epoch: 189
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 25.8005 dB
# Epoch: 190
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.8291 dB
# Epoch: 191
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.8465 dB
# Epoch: 192
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8627 dB
# Epoch: 193
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 25.8417 dB
# Epoch: 194
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8901 dB
# Epoch: 195
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.5454 dB
# Epoch: 196
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8313 dB
# Epoch: 197
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8553 dB
# Epoch: 198
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 25.9007 dB
# Epoch: 199
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 25.9614 dB
# Epoch: 200
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9181 dB
# Epoch: 201
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.9905 dB
# Epoch: 202
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0035 dB
# Epoch: 203
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0128 dB
# Epoch: 204
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0254 dB
# Epoch: 205
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0446 dB
# Epoch: 206
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0511 dB
# Epoch: 207
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0678 dB
# Epoch: 208
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0048 dB
# Epoch: 209
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.4493 dB
# Epoch: 210
# ===> Train: Avg. Loss: 0.0028
# ===> Test: Avg. PSNR: 26.0492 dB
# Epoch: 211
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.0631 dB
# Epoch: 212
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0316 dB
# Epoch: 213
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0902 dB
# Epoch: 214
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 25.9779 dB
# Epoch: 215
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.1108 dB
# Epoch: 216
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0963 dB
# Epoch: 217
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1616 dB
# Epoch: 218
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.9799 dB
# Epoch: 219
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.1783 dB
# Epoch: 220
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.1469 dB
# Epoch: 221
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.9615 dB
# Epoch: 222
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.0015 dB
# Epoch: 223
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2057 dB
# Epoch: 224
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2176 dB
# Epoch: 225
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2214 dB
# Epoch: 226
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2156 dB
# Epoch: 227
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.0546 dB
# Epoch: 228
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.0988 dB
# Epoch: 229
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.1938 dB
# Epoch: 230
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1477 dB
# Epoch: 231
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2247 dB
# Epoch: 232
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2682 dB
# Epoch: 233
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.2152 dB
# Epoch: 234
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2801 dB
# Epoch: 235
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2939 dB
# Epoch: 236
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2772 dB
# Epoch: 237
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2998 dB
# Epoch: 238
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2429 dB
# Epoch: 239
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.2729 dB
# Epoch: 240
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3099 dB
# Epoch: 241
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3241 dB
# Epoch: 242
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.2702 dB
# Epoch: 243
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3467 dB
# Epoch: 244
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2982 dB
# Epoch: 245
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3398 dB
# Epoch: 246
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3097 dB
# Epoch: 247
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3062 dB
# Epoch: 248
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3652 dB
# Epoch: 249
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3512 dB
# Epoch: 250
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1521 dB
# Epoch: 251
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.8153 dB
# Epoch: 252
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.2221 dB
# Epoch: 253
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3649 dB
# Epoch: 254
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3613 dB
# Epoch: 255
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.3915 dB
# Epoch: 256
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.8861 dB
# Epoch: 257
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2395 dB
# Epoch: 258
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.0890 dB
# Epoch: 259
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3570 dB
# Epoch: 260
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4100 dB
# Epoch: 261
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4365 dB
# Epoch: 262
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.3943 dB
# Epoch: 263
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4325 dB
# Epoch: 264
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4365 dB
# Epoch: 265
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3799 dB
# Epoch: 266
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.2467 dB
# Epoch: 267
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.4514 dB
# Epoch: 268
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4514 dB
# Epoch: 269
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.3176 dB
# Epoch: 270
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 24.3910 dB
# Epoch: 271
# ===> Train: Avg. Loss: 0.0029
# ===> Test: Avg. PSNR: 26.1496 dB
# Epoch: 272
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 25.1337 dB
# Epoch: 273
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 24.6299 dB
# Epoch: 274
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 26.0529 dB
# Epoch: 275
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 24.6947 dB
# Epoch: 276
# ===> Train: Avg. Loss: 0.0027
# ===> Test: Avg. PSNR: 26.2036 dB
# Epoch: 277
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.3381 dB
# Epoch: 278
# ===> Train: Avg. Loss: 0.0025
# ===> Test: Avg. PSNR: 26.2626 dB
# Epoch: 279
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.7737 dB
# Epoch: 280
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.4481 dB
# Epoch: 281
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3222 dB
# Epoch: 282
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.4970 dB
# Epoch: 283
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.3963 dB
# Epoch: 284
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.4040 dB
# Epoch: 285
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4693 dB
# Epoch: 286
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5214 dB
# Epoch: 287
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.5053 dB
# Epoch: 288
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4927 dB
# Epoch: 289
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.4725 dB
# Epoch: 290
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5474 dB
# Epoch: 291
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5524 dB
# Epoch: 292
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.5466 dB
# Epoch: 293
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5399 dB
# Epoch: 294
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5324 dB
# Epoch: 295
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.5397 dB
# Epoch: 296
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5308 dB
# Epoch: 297
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5269 dB
# Epoch: 298
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5559 dB
# Epoch: 299
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5720 dB
# Epoch: 300
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5704 dB
# Epoch: 301
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5856 dB
# Epoch: 302
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5789 dB
# Epoch: 303
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5928 dB
# Epoch: 304
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6021 dB
# Epoch: 305
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6063 dB
# Epoch: 306
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.6125 dB
# Epoch: 307
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6159 dB
# Epoch: 308
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6185 dB
# Epoch: 309
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.5905 dB
# Epoch: 310
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6009 dB
# Epoch: 311
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.6251 dB
# Epoch: 312
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6252 dB
# Epoch: 313
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6364 dB
# Epoch: 314
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6413 dB
# Epoch: 315
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6424 dB
# Epoch: 316
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6137 dB
# Epoch: 317
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6508 dB
# Epoch: 318
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6378 dB
# Epoch: 319
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6561 dB
# Epoch: 320
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.6592 dB
# Epoch: 321
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6359 dB
# Epoch: 322
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6650 dB
# Epoch: 323
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6673 dB
# Epoch: 324
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6604 dB
# Epoch: 325
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4432 dB
# Epoch: 326
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.5597 dB
# Epoch: 327
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.1561 dB
# Epoch: 328
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6332 dB
# Epoch: 329
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6712 dB
# Epoch: 330
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6382 dB
# Epoch: 331
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5659 dB
# Epoch: 332
# ===> Train: Avg. Loss: 0.0024
# ===> Test: Avg. PSNR: 26.5461 dB
# Epoch: 333
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4567 dB
# Epoch: 334
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6224 dB
# Epoch: 335
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6705 dB
# Epoch: 336
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7033 dB
# Epoch: 337
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6244 dB
# Epoch: 338
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6608 dB
# Epoch: 339
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6257 dB
# Epoch: 340
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6750 dB
# Epoch: 341
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7211 dB
# Epoch: 342
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6847 dB
# Epoch: 343
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.5274 dB
# Epoch: 344
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.7157 dB
# Epoch: 345
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 25.7098 dB
# Epoch: 346
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.1780 dB
# Epoch: 347
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4531 dB
# Epoch: 348
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.4076 dB
# Epoch: 349
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5685 dB
# Epoch: 350
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6985 dB
# Epoch: 351
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7364 dB
# Epoch: 352
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7429 dB
# Epoch: 353
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7275 dB
# Epoch: 354
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7188 dB
# Epoch: 355
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7072 dB
# Epoch: 356
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7531 dB
# Epoch: 357
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7418 dB
# Epoch: 358
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7000 dB
# Epoch: 359
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6686 dB
# Epoch: 360
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7644 dB
# Epoch: 361
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6543 dB
# Epoch: 362
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7469 dB
# Epoch: 363
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.7703 dB
# Epoch: 364
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7513 dB
# Epoch: 365
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7779 dB
# Epoch: 366
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7837 dB
# Epoch: 367
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7077 dB
# Epoch: 368
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6699 dB
# Epoch: 369
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7925 dB
# Epoch: 370
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7244 dB
# Epoch: 371
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7313 dB
# Epoch: 372
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7592 dB
# Epoch: 373
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7210 dB
# Epoch: 374
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7990 dB
# Epoch: 375
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7792 dB
# Epoch: 376
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7947 dB
# Epoch: 377
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.8076 dB
# Epoch: 378
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7435 dB
# Epoch: 379
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.6722 dB
# Epoch: 380
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.7348 dB
# Epoch: 381
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.5816 dB
# Epoch: 382
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7316 dB
# Epoch: 383
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4413 dB
# Epoch: 384
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.3309 dB
# Epoch: 385
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5345 dB
# Epoch: 386
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7985 dB
# Epoch: 387
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7704 dB
# Epoch: 388
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5722 dB
# Epoch: 389
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.4655 dB
# Epoch: 390
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7716 dB
# Epoch: 391
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7892 dB
# Epoch: 392
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.8087 dB
# Epoch: 393
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6167 dB
# Epoch: 394
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 25.1593 dB
# Epoch: 395
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3515 dB
# Epoch: 396
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.1824 dB
# Epoch: 397
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 25.7174 dB
# Epoch: 398
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 25.8769 dB
# Epoch: 399
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.2480 dB
# Epoch: 400
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6909 dB
# Epoch: 401
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6899 dB
# Epoch: 402
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.5253 dB
# Epoch: 403
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5276 dB
# Epoch: 404
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.7581 dB
# Epoch: 405
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4832 dB
# Epoch: 406
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6558 dB
# Epoch: 407
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6673 dB
# Epoch: 408
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7498 dB
# Epoch: 409
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6207 dB
# Epoch: 410
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7432 dB
# Epoch: 411
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6940 dB
# Epoch: 412
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6923 dB
# Epoch: 413
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6766 dB
# Epoch: 414
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.4970 dB
# Epoch: 415
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.3569 dB
# Epoch: 416
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4763 dB
# Epoch: 417
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.5395 dB
# Epoch: 418
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.4835 dB
# Epoch: 419
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.6028 dB
# Epoch: 420
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.5879 dB
# Epoch: 421
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.7055 dB
# Epoch: 422
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7378 dB
# Epoch: 423
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.8209 dB
# Epoch: 424
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.8628 dB
# Epoch: 425
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.8573 dB
# Epoch: 426
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.8958 dB
# Epoch: 427
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.7984 dB
# Epoch: 428
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6111 dB
# Epoch: 429
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.8837 dB
# Epoch: 430
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.8861 dB
# Epoch: 431
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9076 dB
# Epoch: 432
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.8946 dB
# Epoch: 433
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9020 dB
# Epoch: 434
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.9090 dB
# Epoch: 435
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9042 dB
# Epoch: 436
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.8876 dB
# Epoch: 437
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.9182 dB
# Epoch: 438
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9223 dB
# Epoch: 439
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9189 dB
# Epoch: 440
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.6706 dB
# Epoch: 441
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.9043 dB
# Epoch: 442
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.3854 dB
# Epoch: 443
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.7551 dB
# Epoch: 444
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.8573 dB
# Epoch: 445
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.9221 dB
# Epoch: 446
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9195 dB
# Epoch: 447
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.8680 dB
# Epoch: 448
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.8505 dB
# Epoch: 449
# ===> Train: Avg. Loss: 0.0023
# ===> Test: Avg. PSNR: 26.8728 dB
# Epoch: 450
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6509 dB
# Epoch: 451
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.8124 dB
# Epoch: 452
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.8718 dB
# Epoch: 453
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9272 dB
# Epoch: 454
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.9382 dB
# Epoch: 455
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.9406 dB
# Epoch: 456
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9105 dB
# Epoch: 457
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.9440 dB
# Epoch: 458
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9474 dB
# Epoch: 459
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9531 dB
# Epoch: 460
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.9435 dB
# Epoch: 461
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.8631 dB
# Epoch: 462
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.9444 dB
# Epoch: 463
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.6397 dB
# Epoch: 464
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9521 dB
# Epoch: 465
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.8016 dB
# Epoch: 466
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.5180 dB
# Epoch: 467
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.8252 dB
# Epoch: 468
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.9445 dB
# Epoch: 469
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.9334 dB
# Epoch: 470
# ===> Train: Avg. Loss: 0.0021
# ===> Test: Avg. PSNR: 26.8840 dB
# Epoch: 471
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9176 dB
# Epoch: 472
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9381 dB
# Epoch: 473
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9493 dB
# Epoch: 474
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9525 dB
# Epoch: 475
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9457 dB
# Epoch: 476
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.7692 dB
# Epoch: 477
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.8691 dB
# Epoch: 478
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.9584 dB
# Epoch: 479
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9707 dB
# Epoch: 480
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.8498 dB
# Epoch: 481
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9741 dB
# Epoch: 482
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9626 dB
# Epoch: 483
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9744 dB
# Epoch: 484
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 25.7253 dB
# Epoch: 485
# ===> Train: Avg. Loss: 0.0026
# ===> Test: Avg. PSNR: 26.2991 dB
# Epoch: 486
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.2827 dB
# Epoch: 487
# ===> Train: Avg. Loss: 0.0022
# ===> Test: Avg. PSNR: 26.7207 dB
# Epoch: 488
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.8638 dB
# Epoch: 489
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9050 dB
# Epoch: 490
# ===> Train: Avg. Loss: 0.0020
# ===> Test: Avg. PSNR: 26.9582 dB
# Epoch: 491
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9733 dB
# Epoch: 492
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9777 dB
# Epoch: 493
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9165 dB
# Epoch: 494
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9824 dB
# Epoch: 495
# ===> Train: Avg. Loss: 0.0019
# ===> Test: Avg. PSNR: 26.9694 dB
# Epoch: 496
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9703 dB
# Epoch: 497
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.9854 dB
# Epoch: 498
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.9880 dB
# Epoch: 499
# ===> Train: Avg. Loss: 0.0018
# ===> Test: Avg. PSNR: 26.9326 dB
# Epoch: 500
# ===> Train: Avg. Loss: 0.0017
# ===> Test: Avg. PSNR: 26.9862 dB
# Checkpoint saved to model_epoch500extend_epoch_500.pth

# %% [markdown]
# ###3.2 Change network architecture
#
# The baseline architecture is as:
#
# ---
# Input Y: H x W x 1
#
# ---
# Conv1 x ReLU:
#
# H x W x 1 --> H x W x 64
#
# ---
# Conv2 x ReLU:
#
# H x W x 64 --> H x W x 64
#
# ---
# Conv3 x ReLU:
#
# H x W x 64 --> H x W x 32
#
# ---
# Conv4:
#
# H x W x 32 --> H x W x (upscale_factor ** 2)
#
# ---
# Pixel_Shuffle:
#
# H x W x (upscale_factor ** 2) --> H' x W' x 1
#
# ---
#
# And the code is as:
#
# ```
# self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
# self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
# self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
# self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
# self.pixel_shuffle = nn.PixelShuffle(upscale_factor)
# ```

# %%
# Net
class Net(nn.Module):
    def __init__(self, upscale_factor):
        super(Net, self).__init__()

        ## Baseline
        # self.relu = nn.ReLU()
        # self.conv1 = nn.Conv2d(1, 64, (5, 5), (1, 1), (2, 2))
        # self.conv2 = nn.Conv2d(64, 64, (3, 3), (1, 1), (1, 1))
        # self.conv3 = nn.Conv2d(64, 32, (3, 3), (1, 1), (1, 1))
        # self.conv4 = nn.Conv2d(32, upscale_factor ** 2, (3, 3), (1, 1), (1, 1))
        # self.pixel_shuffle = nn.PixelShuffle(upscale_factor)

        ## Code your network below


        self._initialize_weights()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.relu(self.conv3(x))
        x = self.pixel_shuffle(self.conv4(x))
        return x

    def _initialize_weights(self):
        init.orthogonal_(self.conv1.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv2.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv3.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv4.weight)


# Baseline
torch.manual_seed(args['seed'])
model = Net(upscale_factor=args['upscale_factor']).cuda()
training_loss_fn = nn.MSELoss()
mse_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=args['lr'])
train_set = get_training_set(args['root_dir'], args['upscale_factor'])
test_set = get_test_set(args['root_dir'], args['upscale_factor'])
training_data_loader = DataLoader(dataset=train_set, num_workers=args['threads'], batch_size=args['batchSize'], shuffle=True)
testing_data_loader = DataLoader(dataset=test_set, num_workers=args['threads'], batch_size=args['testBatchSize'], shuffle=False)

extendNet_train_errors = []
extendNet_test_psnrs = []

for epoch in range(1, args['nEpochs'] + 1):
    train_error = train(epoch)
    test_psnr = test()
    extendNet_train_errors.append(train_error)
    extendNet_test_psnrs.append(test_psnr)
save_checkpoint(args['nEpochs'], model_name='model_extendNet')

## Plotting below, please refer the previous code for how to plot training loss and validation PSNR.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-78bae8efa915> in <cell line: 0>()
#      33 # Baseline
#      34 torch.manual_seed(args['seed'])
# ---> 35 model = Net(upscale_factor=args['upscale_factor']).cuda()
#      36 training_loss_fn = nn.MSELoss()
#      37 mse_fn = nn.MSELoss()
#
# <ipython-input-26-78bae8efa915> in __init__(self, upscale_factor)
#      15
#      16
# ---> 17         self._initialize_weights()
#      18
#      19     def forward(self, x):
#
# <ipython-input-26-78bae8efa915> in _initialize_weights(self)
#      25
#      26     def _initialize_weights(self):
# ---> 27         init.orthogonal_(self.conv1.weight, init.calculate_gain('relu'))
#      28         init.orthogonal_(self.conv2.weight, init.calculate_gain('relu'))
#      29         init.orthogonal_(self.conv3.weight, init.calculate_gain('relu'))
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1926             if name in modules:
#    1927                 return modules[name]
# -> 1928         raise AttributeError(
#    1929             f"'{type(self).__name__}' object has no attribute '{name}'"
#    1930         )
#
# AttributeError: 'Net' object has no attribute 'conv1'

# %% [markdown]
# # References:
#
# PyTorch Examples: https://github.com/pytorch/examples/
#
# Plotting: https://www.pluralsight.com/guides/data-visualization-deep-learning-model-using-matplotlib
#
# Real-Time Single Image and Video Super-Resolution Using an Efficient Sub-Pixel Convolutional Neural Network: https://arxiv.org/pdf/1609.05158.pdf
